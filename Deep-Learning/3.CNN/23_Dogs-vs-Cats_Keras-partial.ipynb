# %% [markdown]
# # Dogs vs Cats
# ## Kaggle Dataset의 일부를 이용한 개, 고양이 구분
# ### Dog Image: 1,111개, Cat Image: 1,111개, 총 2,222개
# ### One-hot encoding --> Logistic Regression
# ### Data shuffling
# ### 출처: [pontoregende GitHub](https://github.com/pontorezende/Dogs-vs-Cats-Redux-with-CNN)

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# seed 값 설정
seed = 2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path='dogs-vs-cats/train/'

# %% [markdown]
# ### Train set 만들기

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.5*')
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
# 제대로 load가 되었는지 확인
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
    
    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
y_dogs[0], y_cats[0]
# Out:
# (1, 0)

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_train = np.concatenate((dogs,cats), axis=0)
y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_train)
# Out:
# 2222

# %%
X_train.shape
# Out:
# (2222, 96, 96, 1)

# %% [markdown]
# ### Test Set 만들기

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.12*')
len(glob(dog_path))
# Out:
# 611

# %%
## Load some our dog images (611 개 이미지)
dog_path = os.path.join(path, 'dog.12*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (611 개 이미지)
cat_path = os.path.join(path, 'cat.12*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
# 제대로 load가 되었는지 확인
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
    
    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
y_dogs[0], y_cats[0]
# Out:
# (1, 0)

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_test = np.concatenate((dogs,cats), axis=0)
y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_test)
# Out:
# 1222

# %% [markdown]
# ### CNN 모델 구성

# %%
## CNN모델 구성
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL,1),
          activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 36864)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               18874880
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 18,940,385
# Trainable params: 18,940,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
             optimizer=Adam(), metrics=['accuracy'])

# %%
## to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn-best.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# ### 모델 학습

# %%
model.fit(X_train, y_train, batch_size=32, epochs=40, validation_split=0.2,
          callbacks=[checkpointer, early_stopping_callback],
         shuffle=True)
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.7581 - accuracy: 0.6102
# Epoch 00001: val_loss improved from inf to 0.84821, saving model to model/dogs_vs_cats-cnn-best.hdf5
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.7573 - accuracy: 0.6106 - val_loss: 0.8482 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6587 - accuracy: 0.6301
# Epoch 00002: val_loss improved from 0.84821 to 0.75866, saving model to model/dogs_vs_cats-cnn-best.hdf5
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.6585 - accuracy: 0.6308 - val_loss: 0.7587 - val_accuracy: 0.3573
# Epoch 3/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6411 - accuracy: 0.6511
# Epoch 00003: val_loss did not improve from 0.75866
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6412 - accuracy: 0.6505 - val_loss: 0.9143 - val_accuracy: 0.1798
# Epoch 4/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6248 - accuracy: 0.6585
# Epoch 00004: val_loss did not improve from 0.75866
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6257 - accuracy: 0.6584 - val_loss: 0.8719 - val_accuracy: 0.2494
# Epoch 5/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6396 - accuracy: 0.6528
# Epoch 00005: val_loss did not improve from 0.75866
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6380 - accuracy: 0.6550 - val_loss: 1.0576 - val_accuracy: 0.1820
# Epoch 6/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6286 - accuracy: 0.6733
# Epoch 00006: val_loss did not improve from 0.75866
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6289 - accuracy: 0.6725 - val_loss: 0.8599 - val_accuracy: 0.2180
# Epoch 7/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6131 - accuracy: 0.6716
# Epoch 00007: val_loss did not improve from 0.75866
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6129 - accuracy: 0.6719 - val_loss: 0.9313 - val_accuracy: 0.1978
# Epoch 8/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6085 - accuracy: 0.6864
# Epoch 00008: val_loss did not improve from 0.75866
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6084 - accuracy: 0.6866 - val_loss: 0.8570 - val_accuracy: 0.1775
# Epoch 9/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6052 - accuracy: 0.6852
# Epoch 00009: val_loss did not improve from 0.75866
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6051 - accuracy: 0.6849 - val_loss: 0.8055 - val_accuracy: 0.2517
# Epoch 10/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5750 - accuracy: 0.7045
# Epoch 00010: val_loss did not improve from 0.75866
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.5747 - accuracy: 0.7057 - val_loss: 0.8621 - val_accuracy: 0.3303
# Epoch 11/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5592 - accuracy: 0.7114
# Epoch 00011: val_loss did not improve from 0.75866
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.5587 - accuracy: 0.7119 - val_loss: 0.9281 - val_accuracy: 0.3101
# Epoch 12/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5094 - accuracy: 0.7386
# Epoch 00012: val_loss did not improve from 0.75866
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.5121 - accuracy: 0.7372 - val_loss: 1.1365 - val_accuracy: 0.2202

# %%
from tensorflow.keras.models import load_model
del model
model = load_model('model/dogs_vs_cats-cnn-best.hdf5')

# %%
scores = model.evaluate(X_test, y_test, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 1222/1222 - 2s - loss: 0.6844 - accuracy: 0.5614
# MODEL ACCURACY: 0.56137
