# %% [markdown]
# # Dogs vs Cats
# ## Kaggle Dataset의 일부를 이용한 개, 고양이 구분
# ### Dog Image: 1,111개, Cat Image: 1,111개, 총 2,222개
# ### 출처: [pontoregende GitHub](https://github.com/pontorezende/Dogs-vs-Cats-Redux-with-CNN)

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path='dogs-vs-cats/train/train'

# %% [markdown]
# ### Train set 만들기

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.*')
len(glob(dog_path))
# Out:
# 12500

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
# 제대로 load가 되었는지 확인
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
    
    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
y_dogs[0], y_cats[0]
# Out:
# (1, 0)

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_train = np.concatenate((dogs,cats), axis=0)
y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_train)
# Out:
# 2222

# %%
## One-Hot Encoding
y_train = tf.keras.utils.to_categorical(y_train, 2)

# %%
X_train.shape
# Out:
# (2222, 96, 96, 1)

# %% [markdown]
# ### Test Set 만들기

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.12*')
len(glob(dog_path))
# Out:
# 611

# %%
## Load some our dog images (611 개 이미지)
dog_path = os.path.join(path, 'dog.12*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (611 개 이미지)
cat_path = os.path.join(path, 'cat.12*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
# 제대로 load가 되었는지 확인
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
    
    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
y_dogs[0], y_cats[0]
# Out:
# (1, 0)

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_test = np.concatenate((dogs,cats), axis=0)
y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_test)
# Out:
# 1222

# %%
## One-Hot Encoding
y_test = tf.keras.utils.to_categorical(y_test, 2)

# %% [markdown]
# ### CNN 모델 구성

# %%
## CNN모델 구성
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL,1),
          activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 18,940,898
# Trainable params: 18,940,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
             optimizer=Adam(), metrics=['accuracy'])

# %%
## to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn-best.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# ### 모델 학습

# %%
model.fit(X_train, y_train, batch_size=32, epochs=40, validation_split=0.2,
          callbacks=[checkpointer, early_stopping_callback])
# Out:
# Epoch 1/40
# 56/56 [==============================] - ETA: 0s - loss: 0.7161 - accuracy: 0.6089
# Epoch 00001: val_loss improved from inf to 0.89274, saving model to model/dogs_vs_cats-cnn-best.hdf5
# 56/56 [==============================] - 4s 71ms/step - loss: 0.7161 - accuracy: 0.6089 - val_loss: 0.8927 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.6703 - accuracy: 0.6256
# Epoch 00002: val_loss improved from 0.89274 to 0.84631, saving model to model/dogs_vs_cats-cnn-best.hdf5
# 56/56 [==============================] - 4s 74ms/step - loss: 0.6704 - accuracy: 0.6252 - val_loss: 0.8463 - val_accuracy: 0.0000e+00
# Epoch 3/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.6617 - accuracy: 0.6244
# Epoch 00003: val_loss did not improve from 0.84631
# 56/56 [==============================] - 3s 51ms/step - loss: 0.6619 - accuracy: 0.6246 - val_loss: 0.8815 - val_accuracy: 0.1213
# Epoch 4/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.6381 - accuracy: 0.6585
# Epoch 00004: val_loss improved from 0.84631 to 0.82637, saving model to model/dogs_vs_cats-cnn-best.hdf5
# 56/56 [==============================] - 4s 74ms/step - loss: 0.6391 - accuracy: 0.6573 - val_loss: 0.8264 - val_accuracy: 0.2472
# Epoch 5/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.6422 - accuracy: 0.6528
# Epoch 00005: val_loss did not improve from 0.82637
# 56/56 [==============================] - 3s 50ms/step - loss: 0.6413 - accuracy: 0.6539 - val_loss: 0.9004 - val_accuracy: 0.1753
# Epoch 6/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.6163 - accuracy: 0.6705
# Epoch 00006: val_loss improved from 0.82637 to 0.72044, saving model to model/dogs_vs_cats-cnn-best.hdf5
# 56/56 [==============================] - 4s 73ms/step - loss: 0.6166 - accuracy: 0.6697 - val_loss: 0.7204 - val_accuracy: 0.4562
# Epoch 7/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.6077 - accuracy: 0.6699
# Epoch 00007: val_loss did not improve from 0.72044
# 56/56 [==============================] - 3s 50ms/step - loss: 0.6075 - accuracy: 0.6697 - val_loss: 0.8879 - val_accuracy: 0.1281
# Epoch 8/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.5984 - accuracy: 0.6795
# Epoch 00008: val_loss did not improve from 0.72044
# 56/56 [==============================] - 3s 50ms/step - loss: 0.5984 - accuracy: 0.6792 - val_loss: 1.1109 - val_accuracy: 0.2472
# Epoch 9/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.5567 - accuracy: 0.7068
# Epoch 00009: val_loss did not improve from 0.72044
# 56/56 [==============================] - 3s 50ms/step - loss: 0.5560 - accuracy: 0.7079 - val_loss: 0.7287 - val_accuracy: 0.4292
# Epoch 10/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.5163 - accuracy: 0.7312
# Epoch 00010: val_loss did not improve from 0.72044
# 56/56 [==============================] - 3s 50ms/step - loss: 0.5174 - accuracy: 0.7310 - val_loss: 1.0538 - val_accuracy: 0.2270
# Epoch 11/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.4456 - accuracy: 0.7852
# Epoch 00011: val_loss improved from 0.72044 to 0.72027, saving model to model/dogs_vs_cats-cnn-best.hdf5
# 56/56 [==============================] - 4s 73ms/step - loss: 0.4460 - accuracy: 0.7850 - val_loss: 0.7203 - val_accuracy: 0.5843
# Epoch 12/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.3598 - accuracy: 0.8330
# Epoch 00012: val_loss did not improve from 0.72027
# 56/56 [==============================] - 3s 50ms/step - loss: 0.3597 - accuracy: 0.8317 - val_loss: 0.9167 - val_accuracy: 0.5393
# Epoch 13/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.2650 - accuracy: 0.8989
# Epoch 00013: val_loss did not improve from 0.72027
# 56/56 [==============================] - 3s 50ms/step - loss: 0.2648 - accuracy: 0.8987 - val_loss: 1.4750 - val_accuracy: 0.4652
# Epoch 14/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.2159 - accuracy: 0.9108
# Epoch 00014: val_loss did not improve from 0.72027
# 56/56 [==============================] - 3s 50ms/step - loss: 0.2155 - accuracy: 0.9111 - val_loss: 1.2084 - val_accuracy: 0.5101
# Epoch 15/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.1305 - accuracy: 0.9455
# Epoch 00015: val_loss did not improve from 0.72027
# 56/56 [==============================] - 3s 50ms/step - loss: 0.1317 - accuracy: 0.9454 - val_loss: 1.5481 - val_accuracy: 0.5685
# Epoch 16/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.0934 - accuracy: 0.9653
# Epoch 00016: val_loss did not improve from 0.72027
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0953 - accuracy: 0.9651 - val_loss: 2.0260 - val_accuracy: 0.5079
# Epoch 17/40
# 56/56 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 0.9752
# Epoch 00017: val_loss did not improve from 0.72027
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0807 - accuracy: 0.9752 - val_loss: 2.0165 - val_accuracy: 0.4854
# Epoch 18/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.0666 - accuracy: 0.9801
# Epoch 00018: val_loss did not improve from 0.72027
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0662 - accuracy: 0.9803 - val_loss: 2.0647 - val_accuracy: 0.4854
# Epoch 19/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.0622 - accuracy: 0.9767
# Epoch 00019: val_loss did not improve from 0.72027
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0639 - accuracy: 0.9764 - val_loss: 3.1069 - val_accuracy: 0.4270
# Epoch 20/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.0412 - accuracy: 0.9892
# Epoch 00020: val_loss did not improve from 0.72027
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0413 - accuracy: 0.9887 - val_loss: 1.8604 - val_accuracy: 0.5213
# Epoch 21/40
# 55/56 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9881
# Epoch 00021: val_loss did not improve from 0.72027
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0320 - accuracy: 0.9882 - val_loss: 3.2915 - val_accuracy: 0.4180

# %%
from tensorflow.keras.models import load_model
del model
model = load_model('model/dogs_vs_cats-cnn-best.hdf5')

# %%
scores = model.evaluate(X_test, y_test, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 39/39 - 1s - loss: 0.6971 - accuracy: 0.6416
# MODEL ACCURACY: 0.64157
