# %% [markdown]
# # 베스트 모델 만들기 - 와인 사례
# ## 이진 분류
# ## 베스트 모델 업데이트하기

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('../dataset/wine.csv', header=None)
df = df_pre.sample(frac=1)
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
# 모델 설정
model = Sequential([
    Dense(30, input_dim=12, activation='relu'),
    Dense(12, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
]) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                390
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                372
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 875
# Trainable params: 875
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 컴파일 
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# 모델 저장 폴더 설정
import os
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
# 모델 저장 조건 설정
modelpath = MODEL_DIR + "best{epoch:03d}-{val_loss:.4f}.hdf5"

# checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1)
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)

# %%
# 모델 실행 및 저장
history = model.fit(X, Y, validation_split=0.2, epochs=2000, batch_size=500, 
          verbose=0, callbacks=[checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 0.36768, saving model to ./model/best001-0.3677.hdf5
#
# Epoch 00002: val_loss improved from 0.36768 to 0.29530, saving model to ./model/best002-0.2953.hdf5
#
# Epoch 00003: val_loss improved from 0.29530 to 0.27222, saving model to ./model/best003-0.2722.hdf5
#
# Epoch 00004: val_loss improved from 0.27222 to 0.25892, saving model to ./model/best004-0.2589.hdf5
#
# Epoch 00005: val_loss improved from 0.25892 to 0.24484, saving model to ./model/best005-0.2448.hdf5
#
# Epoch 00006: val_loss improved from 0.24484 to 0.23621, saving model to ./model/best006-0.2362.hdf5
#
# Epoch 00007: val_loss improved from 0.23621 to 0.22868, saving model to ./model/best007-0.2287.hdf5
#
# Epoch 00008: val_loss improved from 0.22868 to 0.22115, saving model to ./model/best008-0.2211.hdf5
#
# Epoch 00009: val_loss improved from 0.22115 to 0.21183, saving model to ./model/best009-0.2118.hdf5
#
# Epoch 00010: val_loss improved from 0.21183 to 0.20271, saving model to ./model/best010-0.2027.hdf5
#
# Epoch 00011: val_loss improved from 0.20271 to 0.19998, saving model to ./model/best011-0.2000.hdf5
#
# Epoch 00012: val_loss improved from 0.19998 to 0.19679, saving model to ./model/best012-0.1968.hdf5
#
# Epoch 00013: val_loss improved from 0.19679 to 0.19373, saving model to ./model/best013-0.1937.hdf5
#
# Epoch 00014: val_loss improved from 0.19373 to 0.19210, saving model to ./model/best014-0.1921.hdf5
#
# Epoch 00015: val_loss improved from 0.19210 to 0.19077, saving model to ./model/best015-0.1908.hdf5
#
# Epoch 00016: val_loss improved from 0.19077 to 0.18987, saving model to ./model/best016-0.1899.hdf5
#
# Epoch 00017: val_loss improved from 0.18987 to 0.18844, saving model to ./model/best017-0.1884.hdf5
#
# Epoch 00018: val_loss improved from 0.18844 to 0.18687, saving model to ./model/best018-0.1869.hdf5
#
# Epoch 00019: val_loss improved from 0.18687 to 0.18634, saving model to ./model/best019-0.1863.hdf5
#
# Epoch 00020: val_loss did not improve from 0.18634
#
# Epoch 00021: val_loss improved from 0.18634 to 0.18435, saving model to ./model/best021-0.1844.hdf5
#
# Epoch 00022: val_loss improved from 0.18435 to 0.18309, saving model to ./model/best022-0.1831.hdf5
#
# Epoch 00023: val_loss improved from 0.18309 to 0.18213, saving model to ./model/best023-0.1821.hdf5
#
# Epoch 00024: val_loss did not improve from 0.18213
#
# Epoch 00025: val_loss improved from 0.18213 to 0.17974, saving model to ./model/best025-0.1797.hdf5
#
# Epoch 00026: val_loss improved from 0.17974 to 0.17814, saving model to ./model/best026-0.1781.hdf5
#
# Epoch 00027: val_loss improved from 0.17814 to 0.17809, saving model to ./model/best027-0.1781.hdf5
#
# Epoch 00028: val_loss improved from 0.17809 to 0.17567, saving model to ./model/best028-0.1757.hdf5
#
# Epoch 00029: val_loss improved from 0.17567 to 0.17476, saving model to ./model/best029-0.1748.hdf5
#
# Epoch 00030: val_loss improved from 0.17476 to 0.17287, saving model to ./model/best030-0.1729.hdf5
#
# Epoch 00031: val_loss did not improve from 0.17287
#
# Epoch 00032: val_loss improved from 0.17287 to 0.16888, saving model to ./model/best032-0.1689.hdf5
#
# Epoch 00033: val_loss improved from 0.16888 to 0.16624, saving model to ./model/best033-0.1662.hdf5
#
# Epoch 00034: val_loss improved from 0.16624 to 0.16491, saving model to ./model/best034-0.1649.hdf5
#
# Epoch 00035: val_loss improved from 0.16491 to 0.16380, saving model to ./model/best035-0.1638.hdf5
#
# Epoch 00036: val_loss improved from 0.16380 to 0.16115, saving model to ./model/best036-0.1611.hdf5
#
# Epoch 00037: val_loss improved from 0.16115 to 0.16074, saving model to ./model/best037-0.1607.hdf5
#
# Epoch 00038: val_loss improved from 0.16074 to 0.15711, saving model to ./model/best038-0.1571.hdf5
#
# Epoch 00039: val_loss improved from 0.15711 to 0.15657, saving model to ./model/best039-0.1566.hdf5
#
# Epoch 00040: val_loss improved from 0.15657 to 0.15427, saving model to ./model/best040-0.1543.hdf5
#
# Epoch 00041: val_loss improved from 0.15427 to 0.15258, saving model to ./model/best041-0.1526.hdf5
#
# Epoch 00042: val_loss did not improve from 0.15258
#
# Epoch 00043: val_loss improved from 0.15258 to 0.15185, saving model to ./model/best043-0.1518.hdf5
#
# Epoch 00044: val_loss did not improve from 0.15185
#
# Epoch 00045: val_loss improved from 0.15185 to 0.14700, saving model to ./model/best045-0.1470.hdf5
#
# Epoch 00046: val_loss improved from 0.14700 to 0.14501, saving model to ./model/best046-0.1450.hdf5
#
# Epoch 00047: val_loss improved from 0.14501 to 0.14227, saving model to ./model/best047-0.1423.hdf5
#
# Epoch 00048: val_loss did not improve from 0.14227
#
# Epoch 00049: val_loss did not improve from 0.14227
#
# Epoch 00050: val_loss improved from 0.14227 to 0.13776, saving model to ./model/best050-0.1378.hdf5
#
# Epoch 00051: val_loss improved from 0.13776 to 0.13662, saving model to ./model/best051-0.1366.hdf5
#
# Epoch 00052: val_loss improved from 0.13662 to 0.13519, saving model to ./model/best052-0.1352.hdf5
#
# Epoch 00053: val_loss improved from 0.13519 to 0.13384, saving model to ./model/best053-0.1338.hdf5
#
# Epoch 00054: val_loss did not improve from 0.13384
#
# Epoch 00055: val_loss improved from 0.13384 to 0.13097, saving model to ./model/best055-0.1310.hdf5
#
# Epoch 00056: val_loss improved from 0.13097 to 0.13009, saving model to ./model/best056-0.1301.hdf5
#
# Epoch 00057: val_loss improved from 0.13009 to 0.12884, saving model to ./model/best057-0.1288.hdf5
#
# Epoch 00058: val_loss did not improve from 0.12884
#
# Epoch 00059: val_loss improved from 0.12884 to 0.12712, saving model to ./model/best059-0.1271.hdf5
#
# Epoch 00060: val_loss did not improve from 0.12712
#
# Epoch 00061: val_loss improved from 0.12712 to 0.12280, saving model to ./model/best061-0.1228.hdf5
#
# Epoch 00062: val_loss improved from 0.12280 to 0.12187, saving model to ./model/best062-0.1219.hdf5
#
# Epoch 00063: val_loss did not improve from 0.12187
#
# Epoch 00064: val_loss did not improve from 0.12187
#
# Epoch 00065: val_loss improved from 0.12187 to 0.11775, saving model to ./model/best065-0.1178.hdf5
#
# Epoch 00066: val_loss did not improve from 0.11775
#
# Epoch 00067: val_loss improved from 0.11775 to 0.11401, saving model to ./model/best067-0.1140.hdf5
#
# Epoch 00068: val_loss improved from 0.11401 to 0.11283, saving model to ./model/best068-0.1128.hdf5
#
# Epoch 00069: val_loss improved from 0.11283 to 0.11168, saving model to ./model/best069-0.1117.hdf5
#
# Epoch 00070: val_loss improved from 0.11168 to 0.11009, saving model to ./model/best070-0.1101.hdf5
#
# Epoch 00071: val_loss improved from 0.11009 to 0.10923, saving model to ./model/best071-0.1092.hdf5
#
# Epoch 00072: val_loss improved from 0.10923 to 0.10775, saving model to ./model/best072-0.1078.hdf5
#
# Epoch 00073: val_loss did not improve from 0.10775
#
# Epoch 00074: val_loss did not improve from 0.10775
#
# Epoch 00075: val_loss improved from 0.10775 to 0.10424, saving model to ./model/best075-0.1042.hdf5
#
# Epoch 00076: val_loss improved from 0.10424 to 0.10369, saving model to ./model/best076-0.1037.hdf5
#
# Epoch 00077: val_loss did not improve from 0.10369
#
# Epoch 00078: val_loss improved from 0.10369 to 0.10115, saving model to ./model/best078-0.1011.hdf5
#
# Epoch 00079: val_loss improved from 0.10115 to 0.10050, saving model to ./model/best079-0.1005.hdf5
#
# Epoch 00080: val_loss improved from 0.10050 to 0.09927, saving model to ./model/best080-0.0993.hdf5
#
# Epoch 00081: val_loss did not improve from 0.09927
#
# Epoch 00082: val_loss did not improve from 0.09927
#
# Epoch 00083: val_loss did not improve from 0.09927
#
# Epoch 00084: val_loss improved from 0.09927 to 0.09540, saving model to ./model/best084-0.0954.hdf5
#
# Epoch 00085: val_loss improved from 0.09540 to 0.09447, saving model to ./model/best085-0.0945.hdf5
#
# Epoch 00086: val_loss improved from 0.09447 to 0.09399, saving model to ./model/best086-0.0940.hdf5
#
# Epoch 00087: val_loss improved from 0.09399 to 0.09308, saving model to ./model/best087-0.0931.hdf5
#
# Epoch 00088: val_loss improved from 0.09308 to 0.09290, saving model to ./model/best088-0.0929.hdf5
#
# Epoch 00089: val_loss improved from 0.09290 to 0.09089, saving model to ./model/best089-0.0909.hdf5
#
# Epoch 00090: val_loss did not improve from 0.09089
#
# Epoch 00091: val_loss improved from 0.09089 to 0.09037, saving model to ./model/best091-0.0904.hdf5
#
# Epoch 00092: val_loss improved from 0.09037 to 0.08891, saving model to ./model/best092-0.0889.hdf5
# Epoch 00093: val_loss did not improve from 0.08891
#
# Epoch 00094: val_loss improved from 0.08891 to 0.08702, saving model to ./model/best094-0.0870.hdf5
#
# Epoch 00095: val_loss did not improve from 0.08702
#
# Epoch 00096: val_loss improved from 0.08702 to 0.08652, saving model to ./model/best096-0.0865.hdf5
#
# Epoch 00097: val_loss did not improve from 0.08652
#
# Epoch 00098: val_loss improved from 0.08652 to 0.08482, saving model to ./model/best098-0.0848.hdf5
#
# Epoch 00099: val_loss did not improve from 0.08482
#
# Epoch 00100: val_loss did not improve from 0.08482
#
# Epoch 00101: val_loss improved from 0.08482 to 0.08152, saving model to ./model/best101-0.0815.hdf5
#
# Epoch 00102: val_loss improved from 0.08152 to 0.08142, saving model to ./model/best102-0.0814.hdf5
#
# Epoch 00103: val_loss improved from 0.08142 to 0.08031, saving model to ./model/best103-0.0803.hdf5
#
# Epoch 00104: val_loss did not improve from 0.08031
#
# Epoch 00105: val_loss improved from 0.08031 to 0.07970, saving model to ./model/best105-0.0797.hdf5
#
# Epoch 00106: val_loss did not improve from 0.07970
#
# Epoch 00107: val_loss did not improve from 0.07970
#
# Epoch 00108: val_loss improved from 0.07970 to 0.07866, saving model to ./model/best108-0.0787.hdf5
#
# Epoch 00109: val_loss improved from 0.07866 to 0.07802, saving model to ./model/best109-0.0780.hdf5
#
# Epoch 00110: val_loss improved from 0.07802 to 0.07673, saving model to ./model/best110-0.0767.hdf5
#
# Epoch 00111: val_loss improved from 0.07673 to 0.07618, saving model to ./model/best111-0.0762.hdf5
#
# Epoch 00112: val_loss improved from 0.07618 to 0.07539, saving model to ./model/best112-0.0754.hdf5
#
# Epoch 00113: val_loss did not improve from 0.07539
#
# Epoch 00114: val_loss did not improve from 0.07539
#
# Epoch 00115: val_loss improved from 0.07539 to 0.07479, saving model to ./model/best115-0.0748.hdf5
#
# Epoch 00116: val_loss improved from 0.07479 to 0.07383, saving model to ./model/best116-0.0738.hdf5
#
# Epoch 00117: val_loss improved from 0.07383 to 0.07376, saving model to ./model/best117-0.0738.hdf5
#
# Epoch 00118: val_loss did not improve from 0.07376
#
# Epoch 00119: val_loss did not improve from 0.07376
#
# Epoch 00120: val_loss improved from 0.07376 to 0.07242, saving model to ./model/best120-0.0724.hdf5
#
# Epoch 00121: val_loss did not improve from 0.07242
#
# Epoch 00122: val_loss did not improve from 0.07242
#
# Epoch 00123: val_loss improved from 0.07242 to 0.07060, saving model to ./model/best123-0.0706.hdf5
#
# Epoch 00124: val_loss improved from 0.07060 to 0.07040, saving model to ./model/best124-0.0704.hdf5
#
# Epoch 00125: val_loss improved from 0.07040 to 0.06953, saving model to ./model/best125-0.0695.hdf5
#
# Epoch 00126: val_loss improved from 0.06953 to 0.06936, saving model to ./model/best126-0.0694.hdf5
#
# Epoch 00127: val_loss did not improve from 0.06936
#
# Epoch 00128: val_loss improved from 0.06936 to 0.06891, saving model to ./model/best128-0.0689.hdf5
#
# Epoch 00129: val_loss did not improve from 0.06891
#
# Epoch 00130: val_loss improved from 0.06891 to 0.06779, saving model to ./model/best130-0.0678.hdf5
#
# Epoch 00131: val_loss did not improve from 0.06779
#
# Epoch 00132: val_loss improved from 0.06779 to 0.06731, saving model to ./model/best132-0.0673.hdf5
#
# Epoch 00133: val_loss improved from 0.06731 to 0.06688, saving model to ./model/best133-0.0669.hdf5
#
# Epoch 00134: val_loss did not improve from 0.06688
#
# Epoch 00135: val_loss did not improve from 0.06688
#
# Epoch 00136: val_loss improved from 0.06688 to 0.06607, saving model to ./model/best136-0.0661.hdf5
#
# Epoch 00137: val_loss improved from 0.06607 to 0.06530, saving model to ./model/best137-0.0653.hdf5
#
# Epoch 00138: val_loss did not improve from 0.06530
#
# Epoch 00139: val_loss did not improve from 0.06530
#
# Epoch 00140: val_loss did not improve from 0.06530
#
# Epoch 00141: val_loss did not improve from 0.06530
#
# Epoch 00142: val_loss did not improve from 0.06530
#
# Epoch 00143: val_loss did not improve from 0.06530
#
# Epoch 00144: val_loss improved from 0.06530 to 0.06381, saving model to ./model/best144-0.0638.hdf5
#
# Epoch 00145: val_loss did not improve from 0.06381
#
# Epoch 00146: val_loss improved from 0.06381 to 0.06284, saving model to ./model/best146-0.0628.hdf5
#
# Epoch 00147: val_loss did not improve from 0.06284
#
# Epoch 00148: val_loss improved from 0.06284 to 0.06246, saving model to ./model/best148-0.0625.hdf5
#
# Epoch 00149: val_loss did not improve from 0.06246
#
# Epoch 00150: val_loss did not improve from 0.06246
#
# Epoch 00151: val_loss did not improve from 0.06246
#
# Epoch 00152: val_loss improved from 0.06246 to 0.06177, saving model to ./model/best152-0.0618.hdf5
#
# Epoch 00153: val_loss did not improve from 0.06177
#
# Epoch 00154: val_loss did not improve from 0.06177
#
# Epoch 00155: val_loss did not improve from 0.06177
#
# Epoch 00156: val_loss improved from 0.06177 to 0.06162, saving model to ./model/best156-0.0616.hdf5
#
# Epoch 00157: val_loss improved from 0.06162 to 0.06074, saving model to ./model/best157-0.0607.hdf5
#
# Epoch 00158: val_loss did not improve from 0.06074
#
# Epoch 00159: val_loss improved from 0.06074 to 0.06072, saving model to ./model/best159-0.0607.hdf5
#
# Epoch 00160: val_loss improved from 0.06072 to 0.06016, saving model to ./model/best160-0.0602.hdf5
#
# Epoch 00161: val_loss did not improve from 0.06016
#
# Epoch 00162: val_loss did not improve from 0.06016
#
# Epoch 00163: val_loss did not improve from 0.06016
#
# Epoch 00164: val_loss did not improve from 0.06016
#
# Epoch 00165: val_loss did not improve from 0.06016
#
# Epoch 00166: val_loss did not improve from 0.06016
#
# Epoch 00167: val_loss did not improve from 0.06016
#
# Epoch 00168: val_loss improved from 0.06016 to 0.05982, saving model to ./model/best168-0.0598.hdf5
#
# Epoch 00169: val_loss did not improve from 0.05982
#
# Epoch 00170: val_loss did not improve from 0.05982
#
# Epoch 00171: val_loss did not improve from 0.05982
#
# Epoch 00172: val_loss improved from 0.05982 to 0.05976, saving model to ./model/best172-0.0598.hdf5
#
# Epoch 00173: val_loss improved from 0.05976 to 0.05904, saving model to ./model/best173-0.0590.hdf5
#
# Epoch 00174: val_loss improved from 0.05904 to 0.05776, saving model to ./model/best174-0.0578.hdf5
#
# Epoch 00175: val_loss did not improve from 0.05776
#
# Epoch 00176: val_loss did not improve from 0.05776
#
# Epoch 00177: val_loss did not improve from 0.05776
#
# Epoch 00178: val_loss did not improve from 0.05776
#
# Epoch 00179: val_loss did not improve from 0.05776
#
# Epoch 00180: val_loss did not improve from 0.05776
#
# Epoch 00181: val_loss improved from 0.05776 to 0.05771, saving model to ./model/best181-0.0577.hdf5
#
# Epoch 00182: val_loss did not improve from 0.05771
#
# Epoch 00183: val_loss did not improve from 0.05771
#
# Epoch 00184: val_loss did not improve from 0.05771
#
# Epoch 00185: val_loss improved from 0.05771 to 0.05676, saving model to ./model/best185-0.0568.hdf5
#
# Epoch 00186: val_loss did not improve from 0.05676
#
# Epoch 00187: val_loss did not improve from 0.05676
#
# Epoch 00188: val_loss did not improve from 0.05676
#
# Epoch 00189: val_loss did not improve from 0.05676
#
# Epoch 00190: val_loss did not improve from 0.05676
#
# Epoch 00191: val_loss did not improve from 0.05676
#
# Epoch 00192: val_loss improved from 0.05676 to 0.05651, saving model to ./model/best192-0.0565.hdf5
#
# Epoch 00193: val_loss improved from 0.05651 to 0.05638, saving model to ./model/best193-0.0564.hdf5
#
# Epoch 00194: val_loss improved from 0.05638 to 0.05597, saving model to ./model/best194-0.0560.hdf5
#
# Epoch 00195: val_loss improved from 0.05597 to 0.05555, saving model to ./model/best195-0.0556.hdf5
#
# Epoch 00196: val_loss did not improve from 0.05555
#
# Epoch 00197: val_loss improved from 0.05555 to 0.05547, saving model to ./model/best197-0.0555.hdf5
#
# Epoch 00198: val_loss did not improve from 0.05547
#
# Epoch 00199: val_loss did not improve from 0.05547
#
# Epoch 00200: val_loss did not improve from 0.05547
#
# Epoch 00201: val_loss did not improve from 0.05547
#
# Epoch 00202: val_loss did not improve from 0.05547
#
# Epoch 00203: val_loss did not improve from 0.05547
#
# Epoch 00204: val_loss improved from 0.05547 to 0.05529, saving model to ./model/best204-0.0553.hdf5
#
# Epoch 00205: val_loss did not improve from 0.05529
#
# Epoch 00206: val_loss did not improve from 0.05529
#
# Epoch 00207: val_loss did not improve from 0.05529
#
# Epoch 00208: val_loss improved from 0.05529 to 0.05462, saving model to ./model/best208-0.0546.hdf5
# Epoch 00209: val_loss did not improve from 0.05462
#
# Epoch 00210: val_loss improved from 0.05462 to 0.05399, saving model to ./model/best210-0.0540.hdf5
#
# Epoch 00211: val_loss did not improve from 0.05399
#
# Epoch 00212: val_loss did not improve from 0.05399
#
# Epoch 00213: val_loss did not improve from 0.05399
#
# Epoch 00214: val_loss did not improve from 0.05399
#
# Epoch 00215: val_loss did not improve from 0.05399
#
# Epoch 00216: val_loss did not improve from 0.05399
#
# Epoch 00217: val_loss did not improve from 0.05399
#
# Epoch 00218: val_loss did not improve from 0.05399
#
# Epoch 00219: val_loss improved from 0.05399 to 0.05391, saving model to ./model/best219-0.0539.hdf5
#
# Epoch 00220: val_loss improved from 0.05391 to 0.05311, saving model to ./model/best220-0.0531.hdf5
#
# Epoch 00221: val_loss did not improve from 0.05311
#
# Epoch 00222: val_loss did not improve from 0.05311
#
# Epoch 00223: val_loss did not improve from 0.05311
#
# Epoch 00224: val_loss did not improve from 0.05311
#
# Epoch 00225: val_loss improved from 0.05311 to 0.05284, saving model to ./model/best225-0.0528.hdf5
#
# Epoch 00226: val_loss did not improve from 0.05284
#
# Epoch 00227: val_loss did not improve from 0.05284
#
# Epoch 00228: val_loss did not improve from 0.05284
#
# Epoch 00229: val_loss did not improve from 0.05284
#
# Epoch 00230: val_loss did not improve from 0.05284
#
# Epoch 00231: val_loss did not improve from 0.05284
#
# Epoch 00232: val_loss improved from 0.05284 to 0.05260, saving model to ./model/best232-0.0526.hdf5
#
# Epoch 00233: val_loss did not improve from 0.05260
#
# Epoch 00234: val_loss did not improve from 0.05260
#
# Epoch 00235: val_loss improved from 0.05260 to 0.05227, saving model to ./model/best235-0.0523.hdf5
#
# Epoch 00236: val_loss did not improve from 0.05227
#
# Epoch 00237: val_loss did not improve from 0.05227
#
# Epoch 00238: val_loss did not improve from 0.05227
#
# Epoch 00239: val_loss did not improve from 0.05227
#
# Epoch 00240: val_loss did not improve from 0.05227
#
# Epoch 00241: val_loss did not improve from 0.05227
#
# Epoch 00242: val_loss did not improve from 0.05227
#
# Epoch 00243: val_loss did not improve from 0.05227
#
# Epoch 00244: val_loss did not improve from 0.05227
#
# Epoch 00245: val_loss did not improve from 0.05227
#
# Epoch 00246: val_loss did not improve from 0.05227
#
# Epoch 00247: val_loss did not improve from 0.05227
#
# Epoch 00248: val_loss did not improve from 0.05227
#
# Epoch 00249: val_loss did not improve from 0.05227
#
# Epoch 00250: val_loss did not improve from 0.05227
#
# Epoch 00251: val_loss did not improve from 0.05227
#
# Epoch 00252: val_loss did not improve from 0.05227
#
# Epoch 00253: val_loss improved from 0.05227 to 0.05213, saving model to ./model/best253-0.0521.hdf5
#
# Epoch 00254: val_loss did not improve from 0.05213
#
# Epoch 00255: val_loss did not improve from 0.05213
#
# Epoch 00256: val_loss did not improve from 0.05213
#
# Epoch 00257: val_loss did not improve from 0.05213
#
# Epoch 00258: val_loss did not improve from 0.05213
#
# Epoch 00259: val_loss did not improve from 0.05213
#
# Epoch 00260: val_loss did not improve from 0.05213
#
# Epoch 00261: val_loss did not improve from 0.05213
#
# Epoch 00262: val_loss did not improve from 0.05213
#
# Epoch 00263: val_loss did not improve from 0.05213
#
# Epoch 00264: val_loss did not improve from 0.05213
#
# Epoch 00265: val_loss did not improve from 0.05213
#
# Epoch 00266: val_loss did not improve from 0.05213
#
# Epoch 00267: val_loss did not improve from 0.05213
#
# Epoch 00268: val_loss did not improve from 0.05213
#
# Epoch 00269: val_loss did not improve from 0.05213
#
# Epoch 00270: val_loss did not improve from 0.05213
#
# Epoch 00271: val_loss did not improve from 0.05213
#
# Epoch 00272: val_loss did not improve from 0.05213
#
# Epoch 00273: val_loss did not improve from 0.05213
#
# Epoch 00274: val_loss did not improve from 0.05213
#
# Epoch 00275: val_loss did not improve from 0.05213
#
# Epoch 00276: val_loss did not improve from 0.05213
#
# Epoch 00277: val_loss did not improve from 0.05213
#
# Epoch 00278: val_loss did not improve from 0.05213
#
# Epoch 00279: val_loss did not improve from 0.05213
#
# Epoch 00280: val_loss did not improve from 0.05213
#
# Epoch 00281: val_loss did not improve from 0.05213
#
# Epoch 00282: val_loss did not improve from 0.05213
#
# Epoch 00283: val_loss did not improve from 0.05213
#
# Epoch 00284: val_loss did not improve from 0.05213
#
# Epoch 00285: val_loss did not improve from 0.05213
#
# Epoch 00286: val_loss did not improve from 0.05213
#
# Epoch 00287: val_loss did not improve from 0.05213
#
# Epoch 00288: val_loss did not improve from 0.05213
#
# Epoch 00289: val_loss did not improve from 0.05213
#
# Epoch 00290: val_loss did not improve from 0.05213
#
# Epoch 00291: val_loss did not improve from 0.05213
#
# Epoch 00292: val_loss did not improve from 0.05213
#
# Epoch 00293: val_loss did not improve from 0.05213
#
# Epoch 00294: val_loss did not improve from 0.05213
#
# Epoch 00295: val_loss did not improve from 0.05213
#
# Epoch 00296: val_loss did not improve from 0.05213
#
# Epoch 00297: val_loss did not improve from 0.05213
#
# Epoch 00298: val_loss did not improve from 0.05213
#
# Epoch 00299: val_loss did not improve from 0.05213
#
# Epoch 00300: val_loss improved from 0.05213 to 0.05173, saving model to ./model/best300-0.0517.hdf5
#
# Epoch 00301: val_loss did not improve from 0.05173
#
# Epoch 00302: val_loss did not improve from 0.05173
#
# Epoch 00303: val_loss did not improve from 0.05173
#
# Epoch 00304: val_loss did not improve from 0.05173
#
# Epoch 00305: val_loss did not improve from 0.05173
#
# Epoch 00306: val_loss did not improve from 0.05173
#
# Epoch 00307: val_loss improved from 0.05173 to 0.05137, saving model to ./model/best307-0.0514.hdf5
#
# Epoch 00308: val_loss did not improve from 0.05137
#
# Epoch 00309: val_loss did not improve from 0.05137
#
# Epoch 00310: val_loss did not improve from 0.05137
#
# Epoch 00311: val_loss did not improve from 0.05137
#
# Epoch 00312: val_loss did not improve from 0.05137
#
# Epoch 00313: val_loss did not improve from 0.05137
#
# Epoch 00314: val_loss did not improve from 0.05137
#
# Epoch 00315: val_loss did not improve from 0.05137
#
# Epoch 00316: val_loss did not improve from 0.05137
#
# Epoch 00317: val_loss did not improve from 0.05137
#
# Epoch 00318: val_loss did not improve from 0.05137
#
# Epoch 00319: val_loss did not improve from 0.05137
#
# Epoch 00320: val_loss did not improve from 0.05137
#
# Epoch 00321: val_loss did not improve from 0.05137
#
# Epoch 00322: val_loss did not improve from 0.05137
#
# Epoch 00323: val_loss did not improve from 0.05137
#
# Epoch 00324: val_loss did not improve from 0.05137
#
# Epoch 00325: val_loss did not improve from 0.05137
#
# Epoch 00326: val_loss did not improve from 0.05137
#
# Epoch 00327: val_loss did not improve from 0.05137
#
# Epoch 00328: val_loss did not improve from 0.05137
#
# Epoch 00329: val_loss did not improve from 0.05137
#
# Epoch 00330: val_loss did not improve from 0.05137
#
# Epoch 00331: val_loss did not improve from 0.05137
#
# Epoch 00332: val_loss did not improve from 0.05137
#
# Epoch 00333: val_loss did not improve from 0.05137
#
# Epoch 00334: val_loss did not improve from 0.05137
#
# Epoch 00335: val_loss did not improve from 0.05137
#
# Epoch 00336: val_loss did not improve from 0.05137
#
# Epoch 00337: val_loss did not improve from 0.05137
#
# Epoch 00338: val_loss did not improve from 0.05137
#
# Epoch 00339: val_loss did not improve from 0.05137
#
# Epoch 00340: val_loss did not improve from 0.05137
#
# Epoch 00341: val_loss did not improve from 0.05137
#
# Epoch 00342: val_loss did not improve from 0.05137
#
# Epoch 00343: val_loss did not improve from 0.05137
#
# Epoch 00344: val_loss did not improve from 0.05137
#
# Epoch 00345: val_loss did not improve from 0.05137
#
# Epoch 00346: val_loss did not improve from 0.05137
#
# Epoch 00347: val_loss did not improve from 0.05137
#
# Epoch 00348: val_loss did not improve from 0.05137
#
# Epoch 00349: val_loss improved from 0.05137 to 0.05119, saving model to ./model/best349-0.0512.hdf5
#
# Epoch 00350: val_loss did not improve from 0.05119
#
# Epoch 00351: val_loss did not improve from 0.05119
#
# Epoch 00352: val_loss did not improve from 0.05119
#
# Epoch 00353: val_loss did not improve from 0.05119
#
# Epoch 00354: val_loss did not improve from 0.05119
#
# Epoch 00355: val_loss did not improve from 0.05119
#
# Epoch 00356: val_loss did not improve from 0.05119
#
# Epoch 00357: val_loss did not improve from 0.05119
#
# Epoch 00358: val_loss did not improve from 0.05119
# Epoch 00359: val_loss did not improve from 0.05119
#
# Epoch 00360: val_loss did not improve from 0.05119
#
# Epoch 00361: val_loss did not improve from 0.05119
#
# Epoch 00362: val_loss did not improve from 0.05119
#
# Epoch 00363: val_loss did not improve from 0.05119
#
# Epoch 00364: val_loss did not improve from 0.05119
#
# Epoch 00365: val_loss did not improve from 0.05119
#
# Epoch 00366: val_loss did not improve from 0.05119
#
# Epoch 00367: val_loss did not improve from 0.05119
#
# Epoch 00368: val_loss did not improve from 0.05119
#
# Epoch 00369: val_loss did not improve from 0.05119
#
# Epoch 00370: val_loss did not improve from 0.05119
#
# Epoch 00371: val_loss did not improve from 0.05119
#
# Epoch 00372: val_loss did not improve from 0.05119
#
# Epoch 00373: val_loss did not improve from 0.05119
#
# Epoch 00374: val_loss did not improve from 0.05119
#
# Epoch 00375: val_loss did not improve from 0.05119
#
# Epoch 00376: val_loss did not improve from 0.05119
#
# Epoch 00377: val_loss did not improve from 0.05119
#
# Epoch 00378: val_loss did not improve from 0.05119
#
# Epoch 00379: val_loss did not improve from 0.05119
#
# Epoch 00380: val_loss did not improve from 0.05119
#
# Epoch 00381: val_loss did not improve from 0.05119
#
# Epoch 00382: val_loss did not improve from 0.05119
#
# Epoch 00383: val_loss did not improve from 0.05119
#
# Epoch 00384: val_loss did not improve from 0.05119
#
# Epoch 00385: val_loss did not improve from 0.05119
#
# Epoch 00386: val_loss did not improve from 0.05119
#
# Epoch 00387: val_loss did not improve from 0.05119
#
# Epoch 00388: val_loss did not improve from 0.05119
#
# Epoch 00389: val_loss did not improve from 0.05119
#
# Epoch 00390: val_loss improved from 0.05119 to 0.05103, saving model to ./model/best390-0.0510.hdf5
#
# Epoch 00391: val_loss did not improve from 0.05103
#
# Epoch 00392: val_loss did not improve from 0.05103
#
# Epoch 00393: val_loss did not improve from 0.05103
#
# Epoch 00394: val_loss did not improve from 0.05103
#
# Epoch 00395: val_loss did not improve from 0.05103
#
# Epoch 00396: val_loss did not improve from 0.05103
#
# Epoch 00397: val_loss did not improve from 0.05103
#
# Epoch 00398: val_loss did not improve from 0.05103
#
# Epoch 00399: val_loss did not improve from 0.05103
#
# Epoch 00400: val_loss did not improve from 0.05103
#
# Epoch 00401: val_loss did not improve from 0.05103
#
# Epoch 00402: val_loss did not improve from 0.05103
#
# Epoch 00403: val_loss did not improve from 0.05103
#
# Epoch 00404: val_loss did not improve from 0.05103
#
# Epoch 00405: val_loss did not improve from 0.05103
#
# Epoch 00406: val_loss did not improve from 0.05103
#
# Epoch 00407: val_loss did not improve from 0.05103
#
# Epoch 00408: val_loss did not improve from 0.05103
#
# Epoch 00409: val_loss did not improve from 0.05103
#
# Epoch 00410: val_loss did not improve from 0.05103
#
# Epoch 00411: val_loss did not improve from 0.05103
#
# Epoch 00412: val_loss did not improve from 0.05103
#
# Epoch 00413: val_loss did not improve from 0.05103
#
# Epoch 00414: val_loss did not improve from 0.05103
#
# Epoch 00415: val_loss did not improve from 0.05103
#
# Epoch 00416: val_loss did not improve from 0.05103
#
# Epoch 00417: val_loss did not improve from 0.05103
#
# Epoch 00418: val_loss did not improve from 0.05103
#
# Epoch 00419: val_loss did not improve from 0.05103
#
# Epoch 00420: val_loss did not improve from 0.05103
#
# Epoch 00421: val_loss improved from 0.05103 to 0.05096, saving model to ./model/best421-0.0510.hdf5
#
# Epoch 00422: val_loss did not improve from 0.05096
#
# Epoch 00423: val_loss did not improve from 0.05096
#
# Epoch 00424: val_loss did not improve from 0.05096
#
# Epoch 00425: val_loss did not improve from 0.05096
#
# Epoch 00426: val_loss did not improve from 0.05096
#
# Epoch 00427: val_loss did not improve from 0.05096
#
# Epoch 00428: val_loss did not improve from 0.05096
#
# Epoch 00429: val_loss did not improve from 0.05096
#
# Epoch 00430: val_loss did not improve from 0.05096
#
# Epoch 00431: val_loss did not improve from 0.05096
#
# Epoch 00432: val_loss did not improve from 0.05096
#
# Epoch 00433: val_loss did not improve from 0.05096
#
# Epoch 00434: val_loss did not improve from 0.05096
#
# Epoch 00435: val_loss did not improve from 0.05096
#
# Epoch 00436: val_loss did not improve from 0.05096
#
# Epoch 00437: val_loss did not improve from 0.05096
#
# Epoch 00438: val_loss did not improve from 0.05096
#
# Epoch 00439: val_loss did not improve from 0.05096
#
# Epoch 00440: val_loss did not improve from 0.05096
#
# Epoch 00441: val_loss did not improve from 0.05096
#
# Epoch 00442: val_loss did not improve from 0.05096
#
# Epoch 00443: val_loss did not improve from 0.05096
#
# Epoch 00444: val_loss did not improve from 0.05096
#
# Epoch 00445: val_loss did not improve from 0.05096
#
# Epoch 00446: val_loss did not improve from 0.05096
#
# Epoch 00447: val_loss did not improve from 0.05096
#
# Epoch 00448: val_loss did not improve from 0.05096
#
# Epoch 00449: val_loss did not improve from 0.05096
#
# Epoch 00450: val_loss did not improve from 0.05096
#
# Epoch 00451: val_loss did not improve from 0.05096
#
# Epoch 00452: val_loss did not improve from 0.05096
#
# Epoch 00453: val_loss did not improve from 0.05096
#
# Epoch 00454: val_loss did not improve from 0.05096
#
# Epoch 00455: val_loss did not improve from 0.05096
#
# Epoch 00456: val_loss did not improve from 0.05096
#
# Epoch 00457: val_loss did not improve from 0.05096
#
# Epoch 00458: val_loss did not improve from 0.05096
#
# Epoch 00459: val_loss did not improve from 0.05096
#
# Epoch 00460: val_loss did not improve from 0.05096
#
# Epoch 00461: val_loss did not improve from 0.05096
#
# Epoch 00462: val_loss did not improve from 0.05096
#
# Epoch 00463: val_loss did not improve from 0.05096
#
# Epoch 00464: val_loss did not improve from 0.05096
#
# Epoch 00465: val_loss did not improve from 0.05096
#
# Epoch 00466: val_loss did not improve from 0.05096
#
# Epoch 00467: val_loss did not improve from 0.05096
#
# Epoch 00468: val_loss did not improve from 0.05096
#
# Epoch 00469: val_loss did not improve from 0.05096
#
# Epoch 00470: val_loss did not improve from 0.05096
#
# Epoch 00471: val_loss did not improve from 0.05096
#
# Epoch 00472: val_loss did not improve from 0.05096
#
# Epoch 00473: val_loss did not improve from 0.05096
#
# Epoch 00474: val_loss did not improve from 0.05096
#
# Epoch 00475: val_loss did not improve from 0.05096
#
# Epoch 00476: val_loss did not improve from 0.05096
#
# Epoch 00477: val_loss did not improve from 0.05096
#
# Epoch 00478: val_loss did not improve from 0.05096
#
# Epoch 00479: val_loss did not improve from 0.05096
#
# Epoch 00480: val_loss did not improve from 0.05096
#
# Epoch 00481: val_loss did not improve from 0.05096
#
# Epoch 00482: val_loss did not improve from 0.05096
#
# Epoch 00483: val_loss improved from 0.05096 to 0.05088, saving model to ./model/best483-0.0509.hdf5
#
# Epoch 00484: val_loss did not improve from 0.05088
#
# Epoch 00485: val_loss did not improve from 0.05088
#
# Epoch 00486: val_loss did not improve from 0.05088
#
# Epoch 00487: val_loss did not improve from 0.05088
#
# Epoch 00488: val_loss did not improve from 0.05088
#
# Epoch 00489: val_loss did not improve from 0.05088
#
# Epoch 00490: val_loss did not improve from 0.05088
#
# Epoch 00491: val_loss did not improve from 0.05088
#
# Epoch 00492: val_loss did not improve from 0.05088
#
# Epoch 00493: val_loss did not improve from 0.05088
#
# Epoch 00494: val_loss did not improve from 0.05088
#
# Epoch 00495: val_loss did not improve from 0.05088
#
# Epoch 00496: val_loss did not improve from 0.05088
#
# Epoch 00497: val_loss did not improve from 0.05088
#
# Epoch 00498: val_loss did not improve from 0.05088
#
# Epoch 00499: val_loss did not improve from 0.05088
#
# Epoch 00500: val_loss did not improve from 0.05088
#
# Epoch 00501: val_loss did not improve from 0.05088
#
# Epoch 00502: val_loss did not improve from 0.05088
#
# Epoch 00503: val_loss did not improve from 0.05088
#
# Epoch 00504: val_loss did not improve from 0.05088
#
# Epoch 00505: val_loss did not improve from 0.05088
#
# Epoch 00506: val_loss did not improve from 0.05088
#
# Epoch 00507: val_loss did not improve from 0.05088
#
# Epoch 00508: val_loss did not improve from 0.05088
#
# Epoch 00509: val_loss did not improve from 0.05088
#
# Epoch 00510: val_loss did not improve from 0.05088
#
# Epoch 00511: val_loss did not improve from 0.05088
#
# Epoch 00512: val_loss did not improve from 0.05088
#
# Epoch 00513: val_loss improved from 0.05088 to 0.05072, saving model to ./model/best513-0.0507.hdf5
# Epoch 00514: val_loss did not improve from 0.05072
#
# Epoch 00515: val_loss did not improve from 0.05072
#
# Epoch 00516: val_loss did not improve from 0.05072
#
# Epoch 00517: val_loss did not improve from 0.05072
#
# Epoch 00518: val_loss did not improve from 0.05072
#
# Epoch 00519: val_loss did not improve from 0.05072
#
# Epoch 00520: val_loss did not improve from 0.05072
#
# Epoch 00521: val_loss did not improve from 0.05072
#
# Epoch 00522: val_loss did not improve from 0.05072
#
# Epoch 00523: val_loss did not improve from 0.05072
#
# Epoch 00524: val_loss improved from 0.05072 to 0.05048, saving model to ./model/best524-0.0505.hdf5
#
# Epoch 00525: val_loss did not improve from 0.05048
#
# Epoch 00526: val_loss did not improve from 0.05048
#
# Epoch 00527: val_loss did not improve from 0.05048
#
# Epoch 00528: val_loss did not improve from 0.05048
#
# Epoch 00529: val_loss did not improve from 0.05048
#
# Epoch 00530: val_loss did not improve from 0.05048
#
# Epoch 00531: val_loss did not improve from 0.05048
#
# Epoch 00532: val_loss did not improve from 0.05048
#
# Epoch 00533: val_loss did not improve from 0.05048
#
# Epoch 00534: val_loss did not improve from 0.05048
#
# Epoch 00535: val_loss did not improve from 0.05048
#
# Epoch 00536: val_loss did not improve from 0.05048
#
# Epoch 00537: val_loss did not improve from 0.05048
#
# Epoch 00538: val_loss did not improve from 0.05048
#
# Epoch 00539: val_loss did not improve from 0.05048
#
# Epoch 00540: val_loss did not improve from 0.05048
#
# Epoch 00541: val_loss did not improve from 0.05048
#
# Epoch 00542: val_loss did not improve from 0.05048
#
# Epoch 00543: val_loss did not improve from 0.05048
#
# Epoch 00544: val_loss did not improve from 0.05048
#
# Epoch 00545: val_loss did not improve from 0.05048
#
# Epoch 00546: val_loss did not improve from 0.05048
#
# Epoch 00547: val_loss did not improve from 0.05048
#
# Epoch 00548: val_loss did not improve from 0.05048
#
# Epoch 00549: val_loss did not improve from 0.05048
#
# Epoch 00550: val_loss did not improve from 0.05048
#
# Epoch 00551: val_loss did not improve from 0.05048
#
# Epoch 00552: val_loss did not improve from 0.05048
#
# Epoch 00553: val_loss did not improve from 0.05048
#
# Epoch 00554: val_loss did not improve from 0.05048
#
# Epoch 00555: val_loss did not improve from 0.05048
#
# Epoch 00556: val_loss did not improve from 0.05048
#
# Epoch 00557: val_loss did not improve from 0.05048
#
# Epoch 00558: val_loss did not improve from 0.05048
#
# Epoch 00559: val_loss did not improve from 0.05048
#
# Epoch 00560: val_loss did not improve from 0.05048
#
# Epoch 00561: val_loss did not improve from 0.05048
#
# Epoch 00562: val_loss did not improve from 0.05048
#
# Epoch 00563: val_loss improved from 0.05048 to 0.04973, saving model to ./model/best563-0.0497.hdf5
#
# Epoch 00564: val_loss did not improve from 0.04973
#
# Epoch 00565: val_loss did not improve from 0.04973
#
# Epoch 00566: val_loss did not improve from 0.04973
#
# Epoch 00567: val_loss did not improve from 0.04973
#
# Epoch 00568: val_loss did not improve from 0.04973
#
# Epoch 00569: val_loss did not improve from 0.04973
#
# Epoch 00570: val_loss did not improve from 0.04973
#
# Epoch 00571: val_loss did not improve from 0.04973
#
# Epoch 00572: val_loss did not improve from 0.04973
#
# Epoch 00573: val_loss did not improve from 0.04973
#
# Epoch 00574: val_loss did not improve from 0.04973
#
# Epoch 00575: val_loss did not improve from 0.04973
#
# Epoch 00576: val_loss did not improve from 0.04973
#
# Epoch 00577: val_loss did not improve from 0.04973
#
# Epoch 00578: val_loss did not improve from 0.04973
#
# Epoch 00579: val_loss did not improve from 0.04973
#
# Epoch 00580: val_loss did not improve from 0.04973
#
# Epoch 00581: val_loss did not improve from 0.04973
#
# Epoch 00582: val_loss did not improve from 0.04973
#
# Epoch 00583: val_loss did not improve from 0.04973
#
# Epoch 00584: val_loss did not improve from 0.04973
#
# Epoch 00585: val_loss did not improve from 0.04973
#
# Epoch 00586: val_loss did not improve from 0.04973
#
# Epoch 00587: val_loss did not improve from 0.04973
#
# Epoch 00588: val_loss did not improve from 0.04973
#
# Epoch 00589: val_loss did not improve from 0.04973
#
# Epoch 00590: val_loss did not improve from 0.04973
#
# Epoch 00591: val_loss did not improve from 0.04973
#
# Epoch 00592: val_loss did not improve from 0.04973
#
# Epoch 00593: val_loss did not improve from 0.04973
#
# Epoch 00594: val_loss did not improve from 0.04973
#
# Epoch 00595: val_loss did not improve from 0.04973
#
# Epoch 00596: val_loss did not improve from 0.04973
#
# Epoch 00597: val_loss did not improve from 0.04973
#
# Epoch 00598: val_loss did not improve from 0.04973
#
# Epoch 00599: val_loss did not improve from 0.04973
#
# Epoch 00600: val_loss did not improve from 0.04973
#
# Epoch 00601: val_loss did not improve from 0.04973
#
# Epoch 00602: val_loss did not improve from 0.04973
#
# Epoch 00603: val_loss did not improve from 0.04973
#
# Epoch 00604: val_loss did not improve from 0.04973
#
# Epoch 00605: val_loss did not improve from 0.04973
#
# Epoch 00606: val_loss did not improve from 0.04973
#
# Epoch 00607: val_loss did not improve from 0.04973
#
# Epoch 00608: val_loss did not improve from 0.04973
#
# Epoch 00609: val_loss did not improve from 0.04973
#
# Epoch 00610: val_loss did not improve from 0.04973
#
# Epoch 00611: val_loss did not improve from 0.04973
#
# Epoch 00612: val_loss did not improve from 0.04973
#
# Epoch 00613: val_loss did not improve from 0.04973
#
# Epoch 00614: val_loss did not improve from 0.04973
#
# Epoch 00615: val_loss did not improve from 0.04973
#
# Epoch 00616: val_loss did not improve from 0.04973
#
# Epoch 00617: val_loss did not improve from 0.04973
#
# Epoch 00618: val_loss did not improve from 0.04973
#
# Epoch 00619: val_loss did not improve from 0.04973
#
# Epoch 00620: val_loss did not improve from 0.04973
#
# Epoch 00621: val_loss did not improve from 0.04973
#
# Epoch 00622: val_loss did not improve from 0.04973
#
# Epoch 00623: val_loss did not improve from 0.04973
#
# Epoch 00624: val_loss did not improve from 0.04973
#
# Epoch 00625: val_loss did not improve from 0.04973
#
# Epoch 00626: val_loss did not improve from 0.04973
#
# Epoch 00627: val_loss did not improve from 0.04973
#
# Epoch 00628: val_loss did not improve from 0.04973
#
# Epoch 00629: val_loss did not improve from 0.04973
#
# Epoch 00630: val_loss did not improve from 0.04973
#
# Epoch 00631: val_loss did not improve from 0.04973
#
# Epoch 00632: val_loss did not improve from 0.04973
#
# Epoch 00633: val_loss did not improve from 0.04973
#
# Epoch 00634: val_loss did not improve from 0.04973
#
# Epoch 00635: val_loss did not improve from 0.04973
#
# Epoch 00636: val_loss did not improve from 0.04973
#
# Epoch 00637: val_loss did not improve from 0.04973
#
# Epoch 00638: val_loss did not improve from 0.04973
#
# Epoch 00639: val_loss did not improve from 0.04973
#
# Epoch 00640: val_loss did not improve from 0.04973
#
# Epoch 00641: val_loss did not improve from 0.04973
#
# Epoch 00642: val_loss did not improve from 0.04973
#
# Epoch 00643: val_loss did not improve from 0.04973
#
# Epoch 00644: val_loss did not improve from 0.04973
#
# Epoch 00645: val_loss did not improve from 0.04973
#
# Epoch 00646: val_loss did not improve from 0.04973
#
# Epoch 00647: val_loss did not improve from 0.04973
#
# Epoch 00648: val_loss did not improve from 0.04973
#
# Epoch 00649: val_loss did not improve from 0.04973
#
# Epoch 00650: val_loss did not improve from 0.04973
#
# Epoch 00651: val_loss did not improve from 0.04973
#
# Epoch 00652: val_loss did not improve from 0.04973
#
# Epoch 00653: val_loss did not improve from 0.04973
#
# Epoch 00654: val_loss did not improve from 0.04973
#
# Epoch 00655: val_loss did not improve from 0.04973
#
# Epoch 00656: val_loss did not improve from 0.04973
#
# Epoch 00657: val_loss did not improve from 0.04973
#
# Epoch 00658: val_loss did not improve from 0.04973
#
# Epoch 00659: val_loss did not improve from 0.04973
#
# Epoch 00660: val_loss did not improve from 0.04973
#
# Epoch 00661: val_loss did not improve from 0.04973
#
# Epoch 00662: val_loss did not improve from 0.04973
#
# Epoch 00663: val_loss did not improve from 0.04973
#
# Epoch 00664: val_loss did not improve from 0.04973
#
# Epoch 00665: val_loss did not improve from 0.04973
#
# Epoch 00666: val_loss did not improve from 0.04973
#
# Epoch 00667: val_loss did not improve from 0.04973
#
# Epoch 00668: val_loss did not improve from 0.04973
#
# Epoch 00669: val_loss did not improve from 0.04973
# Epoch 00670: val_loss did not improve from 0.04973
#
# Epoch 00671: val_loss did not improve from 0.04973
#
# Epoch 00672: val_loss did not improve from 0.04973
#
# Epoch 00673: val_loss did not improve from 0.04973
#
# Epoch 00674: val_loss did not improve from 0.04973
#
# Epoch 00675: val_loss did not improve from 0.04973
#
# Epoch 00676: val_loss did not improve from 0.04973
#
# Epoch 00677: val_loss did not improve from 0.04973
#
# Epoch 00678: val_loss did not improve from 0.04973
#
# Epoch 00679: val_loss did not improve from 0.04973
#
# Epoch 00680: val_loss did not improve from 0.04973
#
# Epoch 00681: val_loss did not improve from 0.04973
#
# Epoch 00682: val_loss did not improve from 0.04973
#
# Epoch 00683: val_loss did not improve from 0.04973
#
# Epoch 00684: val_loss did not improve from 0.04973
#
# Epoch 00685: val_loss did not improve from 0.04973
#
# Epoch 00686: val_loss did not improve from 0.04973
#
# Epoch 00687: val_loss did not improve from 0.04973
#
# Epoch 00688: val_loss did not improve from 0.04973
#
# Epoch 00689: val_loss did not improve from 0.04973
#
# Epoch 00690: val_loss did not improve from 0.04973
#
# Epoch 00691: val_loss did not improve from 0.04973
#
# Epoch 00692: val_loss did not improve from 0.04973
#
# Epoch 00693: val_loss did not improve from 0.04973
#
# Epoch 00694: val_loss did not improve from 0.04973
#
# Epoch 00695: val_loss did not improve from 0.04973
#
# Epoch 00696: val_loss did not improve from 0.04973
#
# Epoch 00697: val_loss did not improve from 0.04973
#
# Epoch 00698: val_loss did not improve from 0.04973
#
# Epoch 00699: val_loss did not improve from 0.04973
#
# Epoch 00700: val_loss did not improve from 0.04973
#
# Epoch 00701: val_loss did not improve from 0.04973
#
# Epoch 00702: val_loss did not improve from 0.04973
#
# Epoch 00703: val_loss did not improve from 0.04973
#
# Epoch 00704: val_loss did not improve from 0.04973
#
# Epoch 00705: val_loss did not improve from 0.04973
#
# Epoch 00706: val_loss did not improve from 0.04973
#
# Epoch 00707: val_loss did not improve from 0.04973
#
# Epoch 00708: val_loss did not improve from 0.04973
#
# Epoch 00709: val_loss did not improve from 0.04973
#
# Epoch 00710: val_loss did not improve from 0.04973
#
# Epoch 00711: val_loss did not improve from 0.04973
#
# Epoch 00712: val_loss did not improve from 0.04973
#
# Epoch 00713: val_loss did not improve from 0.04973
#
# Epoch 00714: val_loss did not improve from 0.04973
#
# Epoch 00715: val_loss did not improve from 0.04973
#
# Epoch 00716: val_loss did not improve from 0.04973
#
# Epoch 00717: val_loss did not improve from 0.04973
#
# Epoch 00718: val_loss did not improve from 0.04973
#
# Epoch 00719: val_loss did not improve from 0.04973
#
# Epoch 00720: val_loss did not improve from 0.04973
#
# Epoch 00721: val_loss did not improve from 0.04973
#
# Epoch 00722: val_loss did not improve from 0.04973
#
# Epoch 00723: val_loss did not improve from 0.04973
#
# Epoch 00724: val_loss did not improve from 0.04973
#
# Epoch 00725: val_loss did not improve from 0.04973
#
# Epoch 00726: val_loss did not improve from 0.04973
#
# Epoch 00727: val_loss did not improve from 0.04973
#
# Epoch 00728: val_loss did not improve from 0.04973
#
# Epoch 00729: val_loss did not improve from 0.04973
#
# Epoch 00730: val_loss did not improve from 0.04973
#
# Epoch 00731: val_loss did not improve from 0.04973
#
# Epoch 00732: val_loss did not improve from 0.04973
#
# Epoch 00733: val_loss did not improve from 0.04973
#
# Epoch 00734: val_loss did not improve from 0.04973
#
# Epoch 00735: val_loss did not improve from 0.04973
#
# Epoch 00736: val_loss did not improve from 0.04973
#
# Epoch 00737: val_loss did not improve from 0.04973
#
# Epoch 00738: val_loss did not improve from 0.04973
#
# Epoch 00739: val_loss did not improve from 0.04973
#
# Epoch 00740: val_loss did not improve from 0.04973
#
# Epoch 00741: val_loss did not improve from 0.04973
#
# Epoch 00742: val_loss did not improve from 0.04973
#
# Epoch 00743: val_loss did not improve from 0.04973
#
# Epoch 00744: val_loss did not improve from 0.04973
#
# Epoch 00745: val_loss did not improve from 0.04973
#
# Epoch 00746: val_loss did not improve from 0.04973
#
# Epoch 00747: val_loss did not improve from 0.04973
#
# Epoch 00748: val_loss did not improve from 0.04973
#
# Epoch 00749: val_loss did not improve from 0.04973
#
# Epoch 00750: val_loss did not improve from 0.04973
#
# Epoch 00751: val_loss did not improve from 0.04973
#
# Epoch 00752: val_loss did not improve from 0.04973
#
# Epoch 00753: val_loss did not improve from 0.04973
#
# Epoch 00754: val_loss did not improve from 0.04973
#
# Epoch 00755: val_loss did not improve from 0.04973
#
# Epoch 00756: val_loss did not improve from 0.04973
#
# Epoch 00757: val_loss did not improve from 0.04973
#
# Epoch 00758: val_loss did not improve from 0.04973
#
# Epoch 00759: val_loss did not improve from 0.04973
#
# Epoch 00760: val_loss did not improve from 0.04973
#
# Epoch 00761: val_loss did not improve from 0.04973
#
# Epoch 00762: val_loss did not improve from 0.04973
#
# Epoch 00763: val_loss did not improve from 0.04973
#
# Epoch 00764: val_loss did not improve from 0.04973
#
# Epoch 00765: val_loss did not improve from 0.04973
#
# Epoch 00766: val_loss did not improve from 0.04973
#
# Epoch 00767: val_loss did not improve from 0.04973
#
# Epoch 00768: val_loss did not improve from 0.04973
#
# Epoch 00769: val_loss did not improve from 0.04973
#
# Epoch 00770: val_loss did not improve from 0.04973
#
# Epoch 00771: val_loss did not improve from 0.04973
#
# Epoch 00772: val_loss did not improve from 0.04973
#
# Epoch 00773: val_loss did not improve from 0.04973
#
# Epoch 00774: val_loss did not improve from 0.04973
#
# Epoch 00775: val_loss did not improve from 0.04973
#
# Epoch 00776: val_loss did not improve from 0.04973
#
# Epoch 00777: val_loss did not improve from 0.04973
#
# Epoch 00778: val_loss did not improve from 0.04973
#
# Epoch 00779: val_loss did not improve from 0.04973
#
# Epoch 00780: val_loss did not improve from 0.04973
#
# Epoch 00781: val_loss did not improve from 0.04973
#
# Epoch 00782: val_loss did not improve from 0.04973
#
# Epoch 00783: val_loss did not improve from 0.04973
#
# Epoch 00784: val_loss did not improve from 0.04973
#
# Epoch 00785: val_loss did not improve from 0.04973
#
# Epoch 00786: val_loss did not improve from 0.04973
#
# Epoch 00787: val_loss did not improve from 0.04973
#
# Epoch 00788: val_loss did not improve from 0.04973
#
# Epoch 00789: val_loss did not improve from 0.04973
#
# Epoch 00790: val_loss did not improve from 0.04973
#
# Epoch 00791: val_loss did not improve from 0.04973
#
# Epoch 00792: val_loss did not improve from 0.04973
#
# Epoch 00793: val_loss did not improve from 0.04973
#
# Epoch 00794: val_loss did not improve from 0.04973
#
# Epoch 00795: val_loss did not improve from 0.04973
#
# Epoch 00796: val_loss did not improve from 0.04973
#
# ...
#
# Epoch 01694: val_loss did not improve from 0.04739
#
# Epoch 01695: val_loss did not improve from 0.04739
#
# Epoch 01696: val_loss did not improve from 0.04739
#
# Epoch 01697: val_loss did not improve from 0.04739
#
# Epoch 01698: val_loss did not improve from 0.04739
#
# Epoch 01699: val_loss did not improve from 0.04739
#
# Epoch 01700: val_loss did not improve from 0.04739
#
# Epoch 01701: val_loss did not improve from 0.04739
#
# Epoch 01702: val_loss did not improve from 0.04739
#
# Epoch 01703: val_loss did not improve from 0.04739
#
# Epoch 01704: val_loss did not improve from 0.04739
#
# Epoch 01705: val_loss did not improve from 0.04739
#
# Epoch 01706: val_loss did not improve from 0.04739
#
# Epoch 01707: val_loss did not improve from 0.04739
#
# Epoch 01708: val_loss did not improve from 0.04739
#
# Epoch 01709: val_loss did not improve from 0.04739
#
# Epoch 01710: val_loss did not improve from 0.04739
#
# Epoch 01711: val_loss did not improve from 0.04739
#
# Epoch 01712: val_loss did not improve from 0.04739
#
# Epoch 01713: val_loss did not improve from 0.04739
#
# Epoch 01714: val_loss did not improve from 0.04739
#
# Epoch 01715: val_loss did not improve from 0.04739
#
# Epoch 01716: val_loss did not improve from 0.04739
#
# Epoch 01717: val_loss did not improve from 0.04739
#
# Epoch 01718: val_loss did not improve from 0.04739
#
# Epoch 01719: val_loss did not improve from 0.04739
#
# Epoch 01720: val_loss did not improve from 0.04739
#
# Epoch 01721: val_loss did not improve from 0.04739
#
# Epoch 01722: val_loss did not improve from 0.04739
#
# Epoch 01723: val_loss did not improve from 0.04739
#
# Epoch 01724: val_loss did not improve from 0.04739
#
# Epoch 01725: val_loss did not improve from 0.04739
#
# Epoch 01726: val_loss did not improve from 0.04739
#
# Epoch 01727: val_loss did not improve from 0.04739
#
# Epoch 01728: val_loss did not improve from 0.04739
#
# Epoch 01729: val_loss did not improve from 0.04739
#
# Epoch 01730: val_loss did not improve from 0.04739
#
# Epoch 01731: val_loss did not improve from 0.04739
#
# Epoch 01732: val_loss did not improve from 0.04739
#
# Epoch 01733: val_loss did not improve from 0.04739
#
# Epoch 01734: val_loss did not improve from 0.04739
#
# Epoch 01735: val_loss did not improve from 0.04739
#
# Epoch 01736: val_loss did not improve from 0.04739
#
# Epoch 01737: val_loss did not improve from 0.04739
#
# Epoch 01738: val_loss did not improve from 0.04739
#
# Epoch 01739: val_loss did not improve from 0.04739
#
# Epoch 01740: val_loss did not improve from 0.04739
#
# Epoch 01741: val_loss did not improve from 0.04739
#
# Epoch 01742: val_loss did not improve from 0.04739
#
# Epoch 01743: val_loss did not improve from 0.04739
#
# Epoch 01744: val_loss did not improve from 0.04739
#
# Epoch 01745: val_loss did not improve from 0.04739
#
# Epoch 01746: val_loss did not improve from 0.04739
#
# Epoch 01747: val_loss did not improve from 0.04739
#
# Epoch 01748: val_loss did not improve from 0.04739
#
# Epoch 01749: val_loss did not improve from 0.04739
#
# Epoch 01750: val_loss did not improve from 0.04739
#
# Epoch 01751: val_loss did not improve from 0.04739
#
# Epoch 01752: val_loss did not improve from 0.04739
#
# Epoch 01753: val_loss did not improve from 0.04739
#
# Epoch 01754: val_loss did not improve from 0.04739
#
# Epoch 01755: val_loss did not improve from 0.04739
#
# Epoch 01756: val_loss did not improve from 0.04739
#
# Epoch 01757: val_loss did not improve from 0.04739
#
# Epoch 01758: val_loss did not improve from 0.04739
#
# Epoch 01759: val_loss did not improve from 0.04739
#
# Epoch 01760: val_loss did not improve from 0.04739
#
# Epoch 01761: val_loss did not improve from 0.04739
#
# Epoch 01762: val_loss did not improve from 0.04739
#
# Epoch 01763: val_loss did not improve from 0.04739
#
# Epoch 01764: val_loss did not improve from 0.04739
#
# Epoch 01765: val_loss did not improve from 0.04739
#
# Epoch 01766: val_loss did not improve from 0.04739
#
# Epoch 01767: val_loss did not improve from 0.04739
#
# Epoch 01768: val_loss did not improve from 0.04739
# Epoch 01769: val_loss did not improve from 0.04739
#
# Epoch 01770: val_loss did not improve from 0.04739
#
# Epoch 01771: val_loss did not improve from 0.04739
#
# Epoch 01772: val_loss did not improve from 0.04739
#
# Epoch 01773: val_loss did not improve from 0.04739
#
# Epoch 01774: val_loss did not improve from 0.04739
#
# Epoch 01775: val_loss did not improve from 0.04739
#
# Epoch 01776: val_loss did not improve from 0.04739
#
# Epoch 01777: val_loss did not improve from 0.04739
#
# Epoch 01778: val_loss did not improve from 0.04739
#
# Epoch 01779: val_loss did not improve from 0.04739
#
# Epoch 01780: val_loss did not improve from 0.04739
#
# Epoch 01781: val_loss did not improve from 0.04739
#
# Epoch 01782: val_loss did not improve from 0.04739
#
# Epoch 01783: val_loss did not improve from 0.04739
#
# Epoch 01784: val_loss did not improve from 0.04739
#
# Epoch 01785: val_loss did not improve from 0.04739
#
# Epoch 01786: val_loss did not improve from 0.04739
#
# Epoch 01787: val_loss did not improve from 0.04739
#
# Epoch 01788: val_loss did not improve from 0.04739
#
# Epoch 01789: val_loss did not improve from 0.04739
#
# Epoch 01790: val_loss did not improve from 0.04739
#
# Epoch 01791: val_loss did not improve from 0.04739
#
# Epoch 01792: val_loss did not improve from 0.04739
#
# Epoch 01793: val_loss did not improve from 0.04739
#
# Epoch 01794: val_loss did not improve from 0.04739
#
# Epoch 01795: val_loss did not improve from 0.04739
#
# Epoch 01796: val_loss did not improve from 0.04739
#
# Epoch 01797: val_loss did not improve from 0.04739
#
# Epoch 01798: val_loss did not improve from 0.04739
#
# Epoch 01799: val_loss did not improve from 0.04739
#
# Epoch 01800: val_loss did not improve from 0.04739
#
# Epoch 01801: val_loss did not improve from 0.04739
#
# Epoch 01802: val_loss did not improve from 0.04739
#
# Epoch 01803: val_loss did not improve from 0.04739
#
# Epoch 01804: val_loss did not improve from 0.04739
#
# Epoch 01805: val_loss did not improve from 0.04739
#
# Epoch 01806: val_loss did not improve from 0.04739
#
# Epoch 01807: val_loss did not improve from 0.04739
#
# Epoch 01808: val_loss did not improve from 0.04739
#
# Epoch 01809: val_loss did not improve from 0.04739
#
# Epoch 01810: val_loss did not improve from 0.04739
#
# Epoch 01811: val_loss did not improve from 0.04739
#
# Epoch 01812: val_loss did not improve from 0.04739
#
# Epoch 01813: val_loss did not improve from 0.04739
#
# Epoch 01814: val_loss did not improve from 0.04739
#
# Epoch 01815: val_loss did not improve from 0.04739
#
# Epoch 01816: val_loss did not improve from 0.04739
#
# Epoch 01817: val_loss did not improve from 0.04739
#
# Epoch 01818: val_loss did not improve from 0.04739
#
# Epoch 01819: val_loss did not improve from 0.04739
#
# Epoch 01820: val_loss did not improve from 0.04739
#
# Epoch 01821: val_loss did not improve from 0.04739
#
# Epoch 01822: val_loss did not improve from 0.04739
#
# Epoch 01823: val_loss did not improve from 0.04739
#
# Epoch 01824: val_loss did not improve from 0.04739
#
# Epoch 01825: val_loss did not improve from 0.04739
#
# Epoch 01826: val_loss did not improve from 0.04739
#
# Epoch 01827: val_loss did not improve from 0.04739
#
# Epoch 01828: val_loss did not improve from 0.04739
#
# Epoch 01829: val_loss did not improve from 0.04739
#
# Epoch 01830: val_loss did not improve from 0.04739
#
# Epoch 01831: val_loss did not improve from 0.04739
#
# Epoch 01832: val_loss did not improve from 0.04739
#
# Epoch 01833: val_loss did not improve from 0.04739
#
# Epoch 01834: val_loss did not improve from 0.04739
#
# Epoch 01835: val_loss did not improve from 0.04739
#
# Epoch 01836: val_loss did not improve from 0.04739
#
# Epoch 01837: val_loss did not improve from 0.04739
#
# Epoch 01838: val_loss did not improve from 0.04739
#
# Epoch 01839: val_loss did not improve from 0.04739
#
# Epoch 01840: val_loss did not improve from 0.04739
#
# Epoch 01841: val_loss did not improve from 0.04739
#
# Epoch 01842: val_loss did not improve from 0.04739
#
# Epoch 01843: val_loss did not improve from 0.04739
#
# Epoch 01844: val_loss did not improve from 0.04739
#
# Epoch 01845: val_loss did not improve from 0.04739
#
# Epoch 01846: val_loss did not improve from 0.04739
#
# Epoch 01847: val_loss did not improve from 0.04739
#
# Epoch 01848: val_loss did not improve from 0.04739
#
# Epoch 01849: val_loss did not improve from 0.04739
#
# Epoch 01850: val_loss did not improve from 0.04739
#
# Epoch 01851: val_loss did not improve from 0.04739
#
# Epoch 01852: val_loss did not improve from 0.04739
#
# Epoch 01853: val_loss did not improve from 0.04739
#
# Epoch 01854: val_loss did not improve from 0.04739
#
# Epoch 01855: val_loss did not improve from 0.04739
#
# Epoch 01856: val_loss did not improve from 0.04739
#
# Epoch 01857: val_loss did not improve from 0.04739
#
# Epoch 01858: val_loss did not improve from 0.04739
#
# Epoch 01859: val_loss did not improve from 0.04739
#
# Epoch 01860: val_loss did not improve from 0.04739
#
# Epoch 01861: val_loss did not improve from 0.04739
#
# Epoch 01862: val_loss did not improve from 0.04739
#
# Epoch 01863: val_loss did not improve from 0.04739
#
# Epoch 01864: val_loss did not improve from 0.04739
#
# Epoch 01865: val_loss did not improve from 0.04739
#
# Epoch 01866: val_loss did not improve from 0.04739
#
# Epoch 01867: val_loss did not improve from 0.04739
#
# Epoch 01868: val_loss did not improve from 0.04739
#
# Epoch 01869: val_loss did not improve from 0.04739
#
# Epoch 01870: val_loss did not improve from 0.04739
#
# Epoch 01871: val_loss did not improve from 0.04739
#
# Epoch 01872: val_loss did not improve from 0.04739
#
# Epoch 01873: val_loss did not improve from 0.04739
#
# Epoch 01874: val_loss did not improve from 0.04739
#
# Epoch 01875: val_loss did not improve from 0.04739
#
# Epoch 01876: val_loss did not improve from 0.04739
#
# Epoch 01877: val_loss did not improve from 0.04739
#
# Epoch 01878: val_loss did not improve from 0.04739
#
# Epoch 01879: val_loss did not improve from 0.04739
#
# Epoch 01880: val_loss did not improve from 0.04739
#
# Epoch 01881: val_loss did not improve from 0.04739
#
# Epoch 01882: val_loss did not improve from 0.04739
#
# Epoch 01883: val_loss did not improve from 0.04739
#
# Epoch 01884: val_loss did not improve from 0.04739
#
# Epoch 01885: val_loss did not improve from 0.04739
#
# Epoch 01886: val_loss did not improve from 0.04739
#
# Epoch 01887: val_loss did not improve from 0.04739
#
# Epoch 01888: val_loss did not improve from 0.04739
#
# Epoch 01889: val_loss did not improve from 0.04739
#
# Epoch 01890: val_loss did not improve from 0.04739
#
# Epoch 01891: val_loss did not improve from 0.04739
#
# Epoch 01892: val_loss did not improve from 0.04739
#
# Epoch 01893: val_loss did not improve from 0.04739
#
# Epoch 01894: val_loss did not improve from 0.04739
#
# Epoch 01895: val_loss did not improve from 0.04739
#
# Epoch 01896: val_loss did not improve from 0.04739
#
# Epoch 01897: val_loss did not improve from 0.04739
#
# Epoch 01898: val_loss did not improve from 0.04739
#
# Epoch 01899: val_loss did not improve from 0.04739
#
# Epoch 01900: val_loss did not improve from 0.04739
#
# Epoch 01901: val_loss did not improve from 0.04739
#
# Epoch 01902: val_loss did not improve from 0.04739
#
# Epoch 01903: val_loss did not improve from 0.04739
#
# Epoch 01904: val_loss did not improve from 0.04739
#
# Epoch 01905: val_loss did not improve from 0.04739
#
# Epoch 01906: val_loss did not improve from 0.04739
#
# Epoch 01907: val_loss did not improve from 0.04739
#
# Epoch 01908: val_loss did not improve from 0.04739
#
# Epoch 01909: val_loss did not improve from 0.04739
#
# Epoch 01910: val_loss did not improve from 0.04739
#
# Epoch 01911: val_loss did not improve from 0.04739
#
# Epoch 01912: val_loss did not improve from 0.04739
#
# Epoch 01913: val_loss did not improve from 0.04739
#
# Epoch 01914: val_loss did not improve from 0.04739
#
# Epoch 01915: val_loss did not improve from 0.04739
#
# Epoch 01916: val_loss did not improve from 0.04739
#
# Epoch 01917: val_loss did not improve from 0.04739
#
# Epoch 01918: val_loss did not improve from 0.04739
#
# Epoch 01919: val_loss did not improve from 0.04739
#
# Epoch 01920: val_loss did not improve from 0.04739
#
# Epoch 01921: val_loss did not improve from 0.04739
#
# Epoch 01922: val_loss did not improve from 0.04739
#
# Epoch 01923: val_loss did not improve from 0.04739
#
# Epoch 01924: val_loss did not improve from 0.04739
#
# Epoch 01925: val_loss did not improve from 0.04739
#
# Epoch 01926: val_loss did not improve from 0.04739
# Epoch 01927: val_loss did not improve from 0.04739
#
# Epoch 01928: val_loss did not improve from 0.04739
#
# Epoch 01929: val_loss did not improve from 0.04739
#
# Epoch 01930: val_loss did not improve from 0.04739
#
# Epoch 01931: val_loss did not improve from 0.04739
#
# Epoch 01932: val_loss did not improve from 0.04739
#
# Epoch 01933: val_loss did not improve from 0.04739
#
# Epoch 01934: val_loss did not improve from 0.04739
#
# Epoch 01935: val_loss did not improve from 0.04739
#
# Epoch 01936: val_loss did not improve from 0.04739
#
# Epoch 01937: val_loss did not improve from 0.04739
#
# Epoch 01938: val_loss did not improve from 0.04739
#
# Epoch 01939: val_loss did not improve from 0.04739
#
# Epoch 01940: val_loss did not improve from 0.04739
#
# Epoch 01941: val_loss did not improve from 0.04739
#
# Epoch 01942: val_loss did not improve from 0.04739
#
# Epoch 01943: val_loss did not improve from 0.04739
#
# Epoch 01944: val_loss did not improve from 0.04739
#
# Epoch 01945: val_loss did not improve from 0.04739
#
# Epoch 01946: val_loss did not improve from 0.04739
#
# Epoch 01947: val_loss did not improve from 0.04739
#
# Epoch 01948: val_loss did not improve from 0.04739
#
# Epoch 01949: val_loss did not improve from 0.04739
#
# Epoch 01950: val_loss did not improve from 0.04739
#
# Epoch 01951: val_loss did not improve from 0.04739
#
# Epoch 01952: val_loss did not improve from 0.04739
#
# Epoch 01953: val_loss did not improve from 0.04739
#
# Epoch 01954: val_loss did not improve from 0.04739
#
# Epoch 01955: val_loss did not improve from 0.04739
#
# Epoch 01956: val_loss did not improve from 0.04739
#
# Epoch 01957: val_loss did not improve from 0.04739
#
# Epoch 01958: val_loss did not improve from 0.04739
#
# Epoch 01959: val_loss did not improve from 0.04739
#
# Epoch 01960: val_loss did not improve from 0.04739
#
# Epoch 01961: val_loss did not improve from 0.04739
#
# Epoch 01962: val_loss did not improve from 0.04739
#
# Epoch 01963: val_loss did not improve from 0.04739
#
# Epoch 01964: val_loss did not improve from 0.04739
#
# Epoch 01965: val_loss did not improve from 0.04739
#
# Epoch 01966: val_loss did not improve from 0.04739
#
# Epoch 01967: val_loss did not improve from 0.04739
#
# Epoch 01968: val_loss did not improve from 0.04739
#
# Epoch 01969: val_loss did not improve from 0.04739
#
# Epoch 01970: val_loss did not improve from 0.04739
#
# Epoch 01971: val_loss did not improve from 0.04739
#
# Epoch 01972: val_loss did not improve from 0.04739
#
# Epoch 01973: val_loss did not improve from 0.04739
#
# Epoch 01974: val_loss did not improve from 0.04739
#
# Epoch 01975: val_loss did not improve from 0.04739
#
# Epoch 01976: val_loss did not improve from 0.04739
#
# Epoch 01977: val_loss did not improve from 0.04739
#
# Epoch 01978: val_loss did not improve from 0.04739
#
# Epoch 01979: val_loss did not improve from 0.04739
#
# Epoch 01980: val_loss did not improve from 0.04739
#
# Epoch 01981: val_loss did not improve from 0.04739
#
# Epoch 01982: val_loss did not improve from 0.04739
#
# Epoch 01983: val_loss did not improve from 0.04739
#
# Epoch 01984: val_loss did not improve from 0.04739
#
# Epoch 01985: val_loss did not improve from 0.04739
#
# Epoch 01986: val_loss did not improve from 0.04739
#
# Epoch 01987: val_loss did not improve from 0.04739
#
# Epoch 01988: val_loss did not improve from 0.04739
#
# Epoch 01989: val_loss did not improve from 0.04739
#
# Epoch 01990: val_loss did not improve from 0.04739
#
# Epoch 01991: val_loss did not improve from 0.04739
#
# Epoch 01992: val_loss did not improve from 0.04739
#
# Epoch 01993: val_loss did not improve from 0.04739
#
# Epoch 01994: val_loss did not improve from 0.04739
#
# Epoch 01995: val_loss did not improve from 0.04739
#
# Epoch 01996: val_loss did not improve from 0.04739
#
# Epoch 01997: val_loss did not improve from 0.04739
#
# Epoch 01998: val_loss did not improve from 0.04739
#
# Epoch 01999: val_loss did not improve from 0.04739
#
# Epoch 02000: val_loss did not improve from 0.04739

# %%
del model

# %%
from tensorflow.keras.models import load_model
model = load_model('model/best190-0.0517.hdf5')

# %%
# 베스트 모델의 결과 출력 
print("\n Accuracy: %.4f" % (model.evaluate(X, Y, verbose=2)[1]))
# Out:
# 6497/1 - 0s - loss: 0.0180 - accuracy: 0.9928
#
#  Accuracy: 0.9928

# %%
import matplotlib.pyplot as plt
#matplotlib inline

y_vloss=history.history['val_loss']
y_acc =history.history['accuracy']

x_len = np.arange(len(y_acc))
plt.plot(x_len, y_vloss, "o", c="red", markersize=3)
plt.plot(x_len, y_acc, "o", c="blue", markersize=3)
