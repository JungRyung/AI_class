# %% [markdown]
# # 베스트 모델 만들기 - 와인 사례
# ## 이진 분류
# ## 베스트 모델 업데이트하기 - 자동 중단, 그래프로 확인

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# seed 값 설정
seed = 2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('../dataset/wine.csv', header=None)
df = df_pre.sample(frac=1)
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
# 모델 설정
model = Sequential([
    Dense(30, input_dim=12, activation='relu'),
    Dense(12, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
]) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                390
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                372
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 875
# Trainable params: 875
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 컴파일 
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# 모델 저장 폴더 설정
import os
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
# 모델 저장 조건 설정
modelpath = MODEL_DIR + "final{epoch:03d}-{val_loss:.4f}.hdf5"

checkpointer_callback = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)

# %%
# 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

# %%
# 모델 실행 및 저장
history = model.fit(X, Y, validation_split=0.33, epochs=3500, batch_size=500,
                    verbose=0, callbacks=[early_stopping_callback, checkpointer_callback])
# Out:
# Epoch 00001: val_loss improved from inf to 2.17685, saving model to ./model/final001-2.1769.hdf5
#
# Epoch 00002: val_loss improved from 2.17685 to 1.24849, saving model to ./model/final002-1.2485.hdf5
#
# Epoch 00003: val_loss improved from 1.24849 to 0.55644, saving model to ./model/final003-0.5564.hdf5
#
# Epoch 00004: val_loss improved from 0.55644 to 0.40663, saving model to ./model/final004-0.4066.hdf5
#
# Epoch 00005: val_loss improved from 0.40663 to 0.35320, saving model to ./model/final005-0.3532.hdf5
#
# Epoch 00006: val_loss improved from 0.35320 to 0.29844, saving model to ./model/final006-0.2984.hdf5
#
# Epoch 00007: val_loss improved from 0.29844 to 0.27093, saving model to ./model/final007-0.2709.hdf5
#
# Epoch 00008: val_loss improved from 0.27093 to 0.25840, saving model to ./model/final008-0.2584.hdf5
#
# Epoch 00009: val_loss improved from 0.25840 to 0.25169, saving model to ./model/final009-0.2517.hdf5
#
# Epoch 00010: val_loss improved from 0.25169 to 0.24636, saving model to ./model/final010-0.2464.hdf5
#
# Epoch 00011: val_loss improved from 0.24636 to 0.24236, saving model to ./model/final011-0.2424.hdf5
#
# Epoch 00012: val_loss improved from 0.24236 to 0.23885, saving model to ./model/final012-0.2389.hdf5
#
# Epoch 00013: val_loss improved from 0.23885 to 0.23547, saving model to ./model/final013-0.2355.hdf5
#
# Epoch 00014: val_loss improved from 0.23547 to 0.23244, saving model to ./model/final014-0.2324.hdf5
#
# Epoch 00015: val_loss improved from 0.23244 to 0.22911, saving model to ./model/final015-0.2291.hdf5
#
# Epoch 00016: val_loss improved from 0.22911 to 0.22629, saving model to ./model/final016-0.2263.hdf5
#
# Epoch 00017: val_loss improved from 0.22629 to 0.22339, saving model to ./model/final017-0.2234.hdf5
#
# Epoch 00018: val_loss improved from 0.22339 to 0.22107, saving model to ./model/final018-0.2211.hdf5
#
# Epoch 00019: val_loss improved from 0.22107 to 0.21761, saving model to ./model/final019-0.2176.hdf5
#
# Epoch 00020: val_loss improved from 0.21761 to 0.21468, saving model to ./model/final020-0.2147.hdf5
#
# Epoch 00021: val_loss improved from 0.21468 to 0.21183, saving model to ./model/final021-0.2118.hdf5
#
# Epoch 00022: val_loss improved from 0.21183 to 0.20946, saving model to ./model/final022-0.2095.hdf5
#
# Epoch 00023: val_loss improved from 0.20946 to 0.20775, saving model to ./model/final023-0.2078.hdf5
#
# Epoch 00024: val_loss improved from 0.20775 to 0.20636, saving model to ./model/final024-0.2064.hdf5
#
# Epoch 00025: val_loss improved from 0.20636 to 0.20351, saving model to ./model/final025-0.2035.hdf5
#
# Epoch 00026: val_loss improved from 0.20351 to 0.20122, saving model to ./model/final026-0.2012.hdf5
#
# Epoch 00027: val_loss improved from 0.20122 to 0.19955, saving model to ./model/final027-0.1996.hdf5
#
# Epoch 00028: val_loss did not improve from 0.19955
#
# Epoch 00029: val_loss did not improve from 0.19955
#
# Epoch 00030: val_loss improved from 0.19955 to 0.19812, saving model to ./model/final030-0.1981.hdf5
#
# Epoch 00031: val_loss improved from 0.19812 to 0.19281, saving model to ./model/final031-0.1928.hdf5
#
# Epoch 00032: val_loss improved from 0.19281 to 0.19148, saving model to ./model/final032-0.1915.hdf5
#
# Epoch 00033: val_loss improved from 0.19148 to 0.18996, saving model to ./model/final033-0.1900.hdf5
#
# Epoch 00034: val_loss improved from 0.18996 to 0.18840, saving model to ./model/final034-0.1884.hdf5
#
# Epoch 00035: val_loss improved from 0.18840 to 0.18718, saving model to ./model/final035-0.1872.hdf5
#
# Epoch 00036: val_loss improved from 0.18718 to 0.18574, saving model to ./model/final036-0.1857.hdf5
#
# Epoch 00037: val_loss improved from 0.18574 to 0.18504, saving model to ./model/final037-0.1850.hdf5
#
# Epoch 00038: val_loss improved from 0.18504 to 0.18338, saving model to ./model/final038-0.1834.hdf5
#
# Epoch 00039: val_loss improved from 0.18338 to 0.18242, saving model to ./model/final039-0.1824.hdf5
#
# Epoch 00040: val_loss improved from 0.18242 to 0.18219, saving model to ./model/final040-0.1822.hdf5
#
# Epoch 00041: val_loss improved from 0.18219 to 0.18037, saving model to ./model/final041-0.1804.hdf5
#
# Epoch 00042: val_loss improved from 0.18037 to 0.17861, saving model to ./model/final042-0.1786.hdf5
#
# Epoch 00043: val_loss improved from 0.17861 to 0.17802, saving model to ./model/final043-0.1780.hdf5
#
# Epoch 00044: val_loss improved from 0.17802 to 0.17612, saving model to ./model/final044-0.1761.hdf5
#
# Epoch 00045: val_loss did not improve from 0.17612
#
# Epoch 00046: val_loss improved from 0.17612 to 0.17543, saving model to ./model/final046-0.1754.hdf5
#
# Epoch 00047: val_loss improved from 0.17543 to 0.17373, saving model to ./model/final047-0.1737.hdf5
#
# Epoch 00048: val_loss improved from 0.17373 to 0.17210, saving model to ./model/final048-0.1721.hdf5
#
# Epoch 00049: val_loss improved from 0.17210 to 0.17087, saving model to ./model/final049-0.1709.hdf5
#
# Epoch 00050: val_loss improved from 0.17087 to 0.16988, saving model to ./model/final050-0.1699.hdf5
#
# Epoch 00051: val_loss did not improve from 0.16988
#
# Epoch 00052: val_loss improved from 0.16988 to 0.16803, saving model to ./model/final052-0.1680.hdf5
#
# Epoch 00053: val_loss did not improve from 0.16803
#
# Epoch 00054: val_loss improved from 0.16803 to 0.16598, saving model to ./model/final054-0.1660.hdf5
#
# Epoch 00055: val_loss did not improve from 0.16598
#
# Epoch 00056: val_loss improved from 0.16598 to 0.16466, saving model to ./model/final056-0.1647.hdf5
#
# Epoch 00057: val_loss improved from 0.16466 to 0.16340, saving model to ./model/final057-0.1634.hdf5
#
# Epoch 00058: val_loss improved from 0.16340 to 0.16242, saving model to ./model/final058-0.1624.hdf5
#
# Epoch 00059: val_loss improved from 0.16242 to 0.16156, saving model to ./model/final059-0.1616.hdf5
#
# Epoch 00060: val_loss improved from 0.16156 to 0.16075, saving model to ./model/final060-0.1607.hdf5
#
# Epoch 00061: val_loss did not improve from 0.16075
#
# Epoch 00062: val_loss improved from 0.16075 to 0.15864, saving model to ./model/final062-0.1586.hdf5
#
# Epoch 00063: val_loss improved from 0.15864 to 0.15782, saving model to ./model/final063-0.1578.hdf5
#
# Epoch 00064: val_loss improved from 0.15782 to 0.15704, saving model to ./model/final064-0.1570.hdf5
#
# Epoch 00065: val_loss improved from 0.15704 to 0.15596, saving model to ./model/final065-0.1560.hdf5
#
# Epoch 00066: val_loss improved from 0.15596 to 0.15511, saving model to ./model/final066-0.1551.hdf5
#
# Epoch 00067: val_loss did not improve from 0.15511
#
# Epoch 00068: val_loss did not improve from 0.15511
#
# Epoch 00069: val_loss improved from 0.15511 to 0.15242, saving model to ./model/final069-0.1524.hdf5
#
# Epoch 00070: val_loss improved from 0.15242 to 0.15188, saving model to ./model/final070-0.1519.hdf5
#
# Epoch 00071: val_loss improved from 0.15188 to 0.15112, saving model to ./model/final071-0.1511.hdf5
#
# Epoch 00072: val_loss improved from 0.15112 to 0.14965, saving model to ./model/final072-0.1497.hdf5
#
# Epoch 00073: val_loss improved from 0.14965 to 0.14908, saving model to ./model/final073-0.1491.hdf5
#
# Epoch 00074: val_loss improved from 0.14908 to 0.14787, saving model to ./model/final074-0.1479.hdf5
#
# Epoch 00075: val_loss did not improve from 0.14787
#
# Epoch 00076: val_loss improved from 0.14787 to 0.14587, saving model to ./model/final076-0.1459.hdf5
#
# Epoch 00077: val_loss did not improve from 0.14587
#
# Epoch 00078: val_loss did not improve from 0.14587
#
# Epoch 00079: val_loss improved from 0.14587 to 0.14330, saving model to ./model/final079-0.1433.hdf5
#
# Epoch 00080: val_loss improved from 0.14330 to 0.14260, saving model to ./model/final080-0.1426.hdf5
#
# Epoch 00081: val_loss did not improve from 0.14260
#
# Epoch 00082: val_loss improved from 0.14260 to 0.14021, saving model to ./model/final082-0.1402.hdf5
#
# Epoch 00083: val_loss did not improve from 0.14021
#
# Epoch 00084: val_loss did not improve from 0.14021
#
# Epoch 00085: val_loss did not improve from 0.14021
#
# Epoch 00086: val_loss improved from 0.14021 to 0.13815, saving model to ./model/final086-0.1381.hdf5
#
# Epoch 00087: val_loss improved from 0.13815 to 0.13661, saving model to ./model/final087-0.1366.hdf5
#
# Epoch 00088: val_loss improved from 0.13661 to 0.13547, saving model to ./model/final088-0.1355.hdf5
#
# Epoch 00089: val_loss did not improve from 0.13547
#
# Epoch 00090: val_loss improved from 0.13547 to 0.13513, saving model to ./model/final090-0.1351.hdf5
# Epoch 00091: val_loss improved from 0.13513 to 0.13301, saving model to ./model/final091-0.1330.hdf5
#
# Epoch 00092: val_loss improved from 0.13301 to 0.13259, saving model to ./model/final092-0.1326.hdf5
#
# Epoch 00093: val_loss improved from 0.13259 to 0.13138, saving model to ./model/final093-0.1314.hdf5
#
# Epoch 00094: val_loss improved from 0.13138 to 0.13037, saving model to ./model/final094-0.1304.hdf5
#
# Epoch 00095: val_loss did not improve from 0.13037
#
# Epoch 00096: val_loss improved from 0.13037 to 0.12902, saving model to ./model/final096-0.1290.hdf5
#
# Epoch 00097: val_loss did not improve from 0.12902
#
# Epoch 00098: val_loss improved from 0.12902 to 0.12677, saving model to ./model/final098-0.1268.hdf5
#
# Epoch 00099: val_loss improved from 0.12677 to 0.12624, saving model to ./model/final099-0.1262.hdf5
#
# Epoch 00100: val_loss improved from 0.12624 to 0.12602, saving model to ./model/final100-0.1260.hdf5
#
# Epoch 00101: val_loss did not improve from 0.12602
#
# Epoch 00102: val_loss did not improve from 0.12602
#
# Epoch 00103: val_loss did not improve from 0.12602
#
# Epoch 00104: val_loss improved from 0.12602 to 0.12284, saving model to ./model/final104-0.1228.hdf5
#
# Epoch 00105: val_loss improved from 0.12284 to 0.12146, saving model to ./model/final105-0.1215.hdf5
#
# Epoch 00106: val_loss did not improve from 0.12146
#
# Epoch 00107: val_loss improved from 0.12146 to 0.12042, saving model to ./model/final107-0.1204.hdf5
#
# Epoch 00108: val_loss did not improve from 0.12042
#
# Epoch 00109: val_loss improved from 0.12042 to 0.11951, saving model to ./model/final109-0.1195.hdf5
#
# Epoch 00110: val_loss did not improve from 0.11951
#
# Epoch 00111: val_loss did not improve from 0.11951
#
# Epoch 00112: val_loss improved from 0.11951 to 0.11683, saving model to ./model/final112-0.1168.hdf5
#
# Epoch 00113: val_loss did not improve from 0.11683
#
# Epoch 00114: val_loss improved from 0.11683 to 0.11581, saving model to ./model/final114-0.1158.hdf5
#
# Epoch 00115: val_loss improved from 0.11581 to 0.11486, saving model to ./model/final115-0.1149.hdf5
#
# Epoch 00116: val_loss improved from 0.11486 to 0.11431, saving model to ./model/final116-0.1143.hdf5
#
# Epoch 00117: val_loss did not improve from 0.11431
#
# Epoch 00118: val_loss did not improve from 0.11431
#
# Epoch 00119: val_loss improved from 0.11431 to 0.11181, saving model to ./model/final119-0.1118.hdf5
#
# Epoch 00120: val_loss did not improve from 0.11181
#
# Epoch 00121: val_loss improved from 0.11181 to 0.11136, saving model to ./model/final121-0.1114.hdf5
#
# Epoch 00122: val_loss did not improve from 0.11136
#
# Epoch 00123: val_loss improved from 0.11136 to 0.11092, saving model to ./model/final123-0.1109.hdf5
#
# Epoch 00124: val_loss improved from 0.11092 to 0.10964, saving model to ./model/final124-0.1096.hdf5
#
# Epoch 00125: val_loss did not improve from 0.10964
#
# Epoch 00126: val_loss improved from 0.10964 to 0.10789, saving model to ./model/final126-0.1079.hdf5
#
# Epoch 00127: val_loss did not improve from 0.10789
#
# Epoch 00128: val_loss improved from 0.10789 to 0.10599, saving model to ./model/final128-0.1060.hdf5
#
# Epoch 00129: val_loss did not improve from 0.10599
#
# Epoch 00130: val_loss did not improve from 0.10599
#
# Epoch 00131: val_loss did not improve from 0.10599
#
# Epoch 00132: val_loss did not improve from 0.10599
#
# Epoch 00133: val_loss did not improve from 0.10599
#
# Epoch 00134: val_loss improved from 0.10599 to 0.10245, saving model to ./model/final134-0.1025.hdf5
#
# Epoch 00135: val_loss improved from 0.10245 to 0.10217, saving model to ./model/final135-0.1022.hdf5
#
# Epoch 00136: val_loss improved from 0.10217 to 0.10192, saving model to ./model/final136-0.1019.hdf5
#
# Epoch 00137: val_loss improved from 0.10192 to 0.10061, saving model to ./model/final137-0.1006.hdf5
#
# Epoch 00138: val_loss improved from 0.10061 to 0.10008, saving model to ./model/final138-0.1001.hdf5
#
# Epoch 00139: val_loss improved from 0.10008 to 0.09990, saving model to ./model/final139-0.0999.hdf5
#
# Epoch 00140: val_loss did not improve from 0.09990
#
# Epoch 00141: val_loss improved from 0.09990 to 0.09844, saving model to ./model/final141-0.0984.hdf5
#
# Epoch 00142: val_loss did not improve from 0.09844
#
# Epoch 00143: val_loss improved from 0.09844 to 0.09733, saving model to ./model/final143-0.0973.hdf5
#
# Epoch 00144: val_loss did not improve from 0.09733
#
# Epoch 00145: val_loss improved from 0.09733 to 0.09717, saving model to ./model/final145-0.0972.hdf5
#
# Epoch 00146: val_loss improved from 0.09717 to 0.09525, saving model to ./model/final146-0.0952.hdf5
#
# Epoch 00147: val_loss did not improve from 0.09525
#
# Epoch 00148: val_loss improved from 0.09525 to 0.09369, saving model to ./model/final148-0.0937.hdf5
#
# Epoch 00149: val_loss did not improve from 0.09369
#
# Epoch 00150: val_loss improved from 0.09369 to 0.09200, saving model to ./model/final150-0.0920.hdf5
#
# Epoch 00151: val_loss did not improve from 0.09200
#
# Epoch 00152: val_loss improved from 0.09200 to 0.09054, saving model to ./model/final152-0.0905.hdf5
#
# Epoch 00153: val_loss improved from 0.09054 to 0.09007, saving model to ./model/final153-0.0901.hdf5
#
# Epoch 00154: val_loss improved from 0.09007 to 0.08896, saving model to ./model/final154-0.0890.hdf5
#
# Epoch 00155: val_loss did not improve from 0.08896
#
# Epoch 00156: val_loss improved from 0.08896 to 0.08881, saving model to ./model/final156-0.0888.hdf5
#
# Epoch 00157: val_loss improved from 0.08881 to 0.08723, saving model to ./model/final157-0.0872.hdf5
#
# Epoch 00158: val_loss did not improve from 0.08723
#
# Epoch 00159: val_loss improved from 0.08723 to 0.08705, saving model to ./model/final159-0.0871.hdf5
#
# Epoch 00160: val_loss improved from 0.08705 to 0.08616, saving model to ./model/final160-0.0862.hdf5
#
# Epoch 00161: val_loss did not improve from 0.08616
#
# Epoch 00162: val_loss did not improve from 0.08616
#
# Epoch 00163: val_loss did not improve from 0.08616
#
# Epoch 00164: val_loss did not improve from 0.08616
#
# Epoch 00165: val_loss did not improve from 0.08616
#
# Epoch 00166: val_loss did not improve from 0.08616
#
# Epoch 00167: val_loss did not improve from 0.08616
#
# Epoch 00168: val_loss did not improve from 0.08616
#
# Epoch 00169: val_loss improved from 0.08616 to 0.08234, saving model to ./model/final169-0.0823.hdf5
#
# Epoch 00170: val_loss improved from 0.08234 to 0.08161, saving model to ./model/final170-0.0816.hdf5
#
# Epoch 00171: val_loss did not improve from 0.08161
#
# Epoch 00172: val_loss did not improve from 0.08161
#
# Epoch 00173: val_loss did not improve from 0.08161
#
# Epoch 00174: val_loss did not improve from 0.08161
#
# Epoch 00175: val_loss did not improve from 0.08161
#
# Epoch 00176: val_loss did not improve from 0.08161
#
# Epoch 00177: val_loss improved from 0.08161 to 0.07912, saving model to ./model/final177-0.0791.hdf5
#
# Epoch 00178: val_loss did not improve from 0.07912
#
# Epoch 00179: val_loss did not improve from 0.07912
#
# Epoch 00180: val_loss did not improve from 0.07912
#
# Epoch 00181: val_loss improved from 0.07912 to 0.07759, saving model to ./model/final181-0.0776.hdf5
#
# Epoch 00182: val_loss improved from 0.07759 to 0.07726, saving model to ./model/final182-0.0773.hdf5
#
# Epoch 00183: val_loss improved from 0.07726 to 0.07689, saving model to ./model/final183-0.0769.hdf5
#
# Epoch 00184: val_loss improved from 0.07689 to 0.07661, saving model to ./model/final184-0.0766.hdf5
#
# Epoch 00185: val_loss improved from 0.07661 to 0.07639, saving model to ./model/final185-0.0764.hdf5
#
# Epoch 00186: val_loss did not improve from 0.07639
#
# Epoch 00187: val_loss improved from 0.07639 to 0.07597, saving model to ./model/final187-0.0760.hdf5
#
# Epoch 00188: val_loss did not improve from 0.07597
#
# Epoch 00189: val_loss did not improve from 0.07597
#
# Epoch 00190: val_loss did not improve from 0.07597
#
# Epoch 00191: val_loss did not improve from 0.07597
#
# Epoch 00192: val_loss did not improve from 0.07597
#
# Epoch 00193: val_loss did not improve from 0.07597
#
# Epoch 00194: val_loss did not improve from 0.07597
#
# Epoch 00195: val_loss improved from 0.07597 to 0.07488, saving model to ./model/final195-0.0749.hdf5
#
# Epoch 00196: val_loss improved from 0.07488 to 0.07409, saving model to ./model/final196-0.0741.hdf5
#
# Epoch 00197: val_loss did not improve from 0.07409
#
# Epoch 00198: val_loss did not improve from 0.07409
# Epoch 00199: val_loss improved from 0.07409 to 0.07352, saving model to ./model/final199-0.0735.hdf5
#
# Epoch 00200: val_loss improved from 0.07352 to 0.07284, saving model to ./model/final200-0.0728.hdf5
#
# Epoch 00201: val_loss did not improve from 0.07284
#
# Epoch 00202: val_loss improved from 0.07284 to 0.07248, saving model to ./model/final202-0.0725.hdf5
#
# Epoch 00203: val_loss improved from 0.07248 to 0.07206, saving model to ./model/final203-0.0721.hdf5
#
# Epoch 00204: val_loss did not improve from 0.07206
#
# Epoch 00205: val_loss did not improve from 0.07206
#
# Epoch 00206: val_loss did not improve from 0.07206
#
# Epoch 00207: val_loss did not improve from 0.07206
#
# Epoch 00208: val_loss improved from 0.07206 to 0.07112, saving model to ./model/final208-0.0711.hdf5
#
# Epoch 00209: val_loss did not improve from 0.07112
#
# Epoch 00210: val_loss did not improve from 0.07112
#
# Epoch 00211: val_loss did not improve from 0.07112
#
# Epoch 00212: val_loss improved from 0.07112 to 0.07088, saving model to ./model/final212-0.0709.hdf5
#
# Epoch 00213: val_loss did not improve from 0.07088
#
# Epoch 00214: val_loss did not improve from 0.07088
#
# Epoch 00215: val_loss improved from 0.07088 to 0.07016, saving model to ./model/final215-0.0702.hdf5
#
# Epoch 00216: val_loss did not improve from 0.07016
#
# Epoch 00217: val_loss did not improve from 0.07016
#
# Epoch 00218: val_loss improved from 0.07016 to 0.07002, saving model to ./model/final218-0.0700.hdf5
#
# Epoch 00219: val_loss did not improve from 0.07002
#
# Epoch 00220: val_loss did not improve from 0.07002
#
# Epoch 00221: val_loss did not improve from 0.07002
#
# Epoch 00222: val_loss did not improve from 0.07002
#
# Epoch 00223: val_loss improved from 0.07002 to 0.06928, saving model to ./model/final223-0.0693.hdf5
#
# Epoch 00224: val_loss did not improve from 0.06928
#
# Epoch 00225: val_loss did not improve from 0.06928
#
# Epoch 00226: val_loss did not improve from 0.06928
#
# Epoch 00227: val_loss improved from 0.06928 to 0.06854, saving model to ./model/final227-0.0685.hdf5
#
# Epoch 00228: val_loss did not improve from 0.06854
#
# Epoch 00229: val_loss did not improve from 0.06854
#
# Epoch 00230: val_loss improved from 0.06854 to 0.06814, saving model to ./model/final230-0.0681.hdf5
#
# Epoch 00231: val_loss did not improve from 0.06814
#
# Epoch 00232: val_loss improved from 0.06814 to 0.06783, saving model to ./model/final232-0.0678.hdf5
#
# Epoch 00233: val_loss did not improve from 0.06783
#
# Epoch 00234: val_loss did not improve from 0.06783
#
# Epoch 00235: val_loss did not improve from 0.06783
#
# Epoch 00236: val_loss did not improve from 0.06783
#
# Epoch 00237: val_loss did not improve from 0.06783
#
# Epoch 00238: val_loss did not improve from 0.06783
#
# Epoch 00239: val_loss did not improve from 0.06783
#
# Epoch 00240: val_loss improved from 0.06783 to 0.06740, saving model to ./model/final240-0.0674.hdf5
#
# Epoch 00241: val_loss improved from 0.06740 to 0.06686, saving model to ./model/final241-0.0669.hdf5
#
# Epoch 00242: val_loss did not improve from 0.06686
#
# Epoch 00243: val_loss did not improve from 0.06686
#
# Epoch 00244: val_loss did not improve from 0.06686
#
# Epoch 00245: val_loss improved from 0.06686 to 0.06680, saving model to ./model/final245-0.0668.hdf5
#
# Epoch 00246: val_loss did not improve from 0.06680
#
# Epoch 00247: val_loss did not improve from 0.06680
#
# Epoch 00248: val_loss improved from 0.06680 to 0.06609, saving model to ./model/final248-0.0661.hdf5
#
# Epoch 00249: val_loss did not improve from 0.06609
#
# Epoch 00250: val_loss did not improve from 0.06609
#
# Epoch 00251: val_loss improved from 0.06609 to 0.06603, saving model to ./model/final251-0.0660.hdf5
#
# Epoch 00252: val_loss did not improve from 0.06603
#
# Epoch 00253: val_loss did not improve from 0.06603
#
# Epoch 00254: val_loss did not improve from 0.06603
#
# Epoch 00255: val_loss did not improve from 0.06603
#
# Epoch 00256: val_loss did not improve from 0.06603
#
# Epoch 00257: val_loss did not improve from 0.06603
#
# Epoch 00258: val_loss did not improve from 0.06603
#
# Epoch 00259: val_loss did not improve from 0.06603
#
# Epoch 00260: val_loss improved from 0.06603 to 0.06554, saving model to ./model/final260-0.0655.hdf5
#
# Epoch 00261: val_loss did not improve from 0.06554
#
# Epoch 00262: val_loss did not improve from 0.06554
#
# Epoch 00263: val_loss improved from 0.06554 to 0.06552, saving model to ./model/final263-0.0655.hdf5
#
# Epoch 00264: val_loss improved from 0.06552 to 0.06530, saving model to ./model/final264-0.0653.hdf5
#
# Epoch 00265: val_loss did not improve from 0.06530
#
# Epoch 00266: val_loss did not improve from 0.06530
#
# Epoch 00267: val_loss did not improve from 0.06530
#
# Epoch 00268: val_loss improved from 0.06530 to 0.06473, saving model to ./model/final268-0.0647.hdf5
#
# Epoch 00269: val_loss did not improve from 0.06473
#
# Epoch 00270: val_loss did not improve from 0.06473
#
# Epoch 00271: val_loss did not improve from 0.06473
#
# Epoch 00272: val_loss did not improve from 0.06473
#
# Epoch 00273: val_loss did not improve from 0.06473
#
# Epoch 00274: val_loss did not improve from 0.06473
#
# Epoch 00275: val_loss did not improve from 0.06473
#
# Epoch 00276: val_loss improved from 0.06473 to 0.06464, saving model to ./model/final276-0.0646.hdf5
#
# Epoch 00277: val_loss did not improve from 0.06464
#
# Epoch 00278: val_loss did not improve from 0.06464
#
# Epoch 00279: val_loss did not improve from 0.06464
#
# Epoch 00280: val_loss improved from 0.06464 to 0.06455, saving model to ./model/final280-0.0646.hdf5
#
# Epoch 00281: val_loss improved from 0.06455 to 0.06425, saving model to ./model/final281-0.0643.hdf5
#
# Epoch 00282: val_loss did not improve from 0.06425
#
# Epoch 00283: val_loss improved from 0.06425 to 0.06405, saving model to ./model/final283-0.0641.hdf5
#
# Epoch 00284: val_loss did not improve from 0.06405
#
# Epoch 00285: val_loss improved from 0.06405 to 0.06365, saving model to ./model/final285-0.0637.hdf5
#
# Epoch 00286: val_loss did not improve from 0.06365
#
# Epoch 00287: val_loss did not improve from 0.06365
#
# Epoch 00288: val_loss did not improve from 0.06365
#
# Epoch 00289: val_loss did not improve from 0.06365
#
# Epoch 00290: val_loss did not improve from 0.06365
#
# Epoch 00291: val_loss did not improve from 0.06365
#
# Epoch 00292: val_loss did not improve from 0.06365
#
# Epoch 00293: val_loss did not improve from 0.06365
#
# Epoch 00294: val_loss improved from 0.06365 to 0.06308, saving model to ./model/final294-0.0631.hdf5
#
# Epoch 00295: val_loss did not improve from 0.06308
#
# Epoch 00296: val_loss did not improve from 0.06308
#
# Epoch 00297: val_loss did not improve from 0.06308
#
# Epoch 00298: val_loss did not improve from 0.06308
#
# Epoch 00299: val_loss did not improve from 0.06308
#
# Epoch 00300: val_loss improved from 0.06308 to 0.06302, saving model to ./model/final300-0.0630.hdf5
#
# Epoch 00301: val_loss did not improve from 0.06302
#
# Epoch 00302: val_loss did not improve from 0.06302
#
# Epoch 00303: val_loss improved from 0.06302 to 0.06269, saving model to ./model/final303-0.0627.hdf5
#
# Epoch 00304: val_loss did not improve from 0.06269
#
# Epoch 00305: val_loss did not improve from 0.06269
#
# Epoch 00306: val_loss did not improve from 0.06269
#
# Epoch 00307: val_loss did not improve from 0.06269
#
# Epoch 00308: val_loss did not improve from 0.06269
#
# Epoch 00309: val_loss did not improve from 0.06269
#
# Epoch 00310: val_loss did not improve from 0.06269
#
# Epoch 00311: val_loss did not improve from 0.06269
#
# Epoch 00312: val_loss did not improve from 0.06269
#
# Epoch 00313: val_loss did not improve from 0.06269
#
# Epoch 00314: val_loss did not improve from 0.06269
#
# Epoch 00315: val_loss did not improve from 0.06269
#
# Epoch 00316: val_loss did not improve from 0.06269
#
# Epoch 00317: val_loss did not improve from 0.06269
#
# Epoch 00318: val_loss did not improve from 0.06269
#
# Epoch 00319: val_loss did not improve from 0.06269
#
# Epoch 00320: val_loss did not improve from 0.06269
#
# Epoch 00321: val_loss did not improve from 0.06269
#
# Epoch 00322: val_loss improved from 0.06269 to 0.06230, saving model to ./model/final322-0.0623.hdf5
#
# Epoch 00323: val_loss did not improve from 0.06230
#
# Epoch 00324: val_loss did not improve from 0.06230
#
# Epoch 00325: val_loss did not improve from 0.06230
#
# Epoch 00326: val_loss did not improve from 0.06230
#
# Epoch 00327: val_loss did not improve from 0.06230
# Epoch 00328: val_loss did not improve from 0.06230
#
# Epoch 00329: val_loss did not improve from 0.06230
#
# Epoch 00330: val_loss did not improve from 0.06230
#
# Epoch 00331: val_loss did not improve from 0.06230
#
# Epoch 00332: val_loss did not improve from 0.06230
#
# Epoch 00333: val_loss did not improve from 0.06230
#
# Epoch 00334: val_loss improved from 0.06230 to 0.06199, saving model to ./model/final334-0.0620.hdf5
#
# Epoch 00335: val_loss did not improve from 0.06199
#
# Epoch 00336: val_loss did not improve from 0.06199
#
# Epoch 00337: val_loss did not improve from 0.06199
#
# Epoch 00338: val_loss did not improve from 0.06199
#
# Epoch 00339: val_loss did not improve from 0.06199
#
# Epoch 00340: val_loss did not improve from 0.06199
#
# Epoch 00341: val_loss did not improve from 0.06199
#
# Epoch 00342: val_loss did not improve from 0.06199
#
# Epoch 00343: val_loss did not improve from 0.06199
#
# Epoch 00344: val_loss did not improve from 0.06199
#
# Epoch 00345: val_loss did not improve from 0.06199
#
# Epoch 00346: val_loss did not improve from 0.06199
#
# Epoch 00347: val_loss did not improve from 0.06199
#
# Epoch 00348: val_loss did not improve from 0.06199
#
# Epoch 00349: val_loss did not improve from 0.06199
#
# Epoch 00350: val_loss did not improve from 0.06199
#
# Epoch 00351: val_loss did not improve from 0.06199
#
# Epoch 00352: val_loss did not improve from 0.06199
#
# Epoch 00353: val_loss did not improve from 0.06199
#
# Epoch 00354: val_loss did not improve from 0.06199
#
# Epoch 00355: val_loss did not improve from 0.06199
#
# Epoch 00356: val_loss did not improve from 0.06199
#
# Epoch 00357: val_loss did not improve from 0.06199
#
# Epoch 00358: val_loss did not improve from 0.06199
#
# Epoch 00359: val_loss did not improve from 0.06199
#
# Epoch 00360: val_loss did not improve from 0.06199
#
# Epoch 00361: val_loss did not improve from 0.06199
#
# Epoch 00362: val_loss did not improve from 0.06199
#
# Epoch 00363: val_loss did not improve from 0.06199
#
# Epoch 00364: val_loss did not improve from 0.06199
#
# Epoch 00365: val_loss did not improve from 0.06199
#
# Epoch 00366: val_loss did not improve from 0.06199
#
# Epoch 00367: val_loss did not improve from 0.06199
#
# Epoch 00368: val_loss did not improve from 0.06199
#
# Epoch 00369: val_loss did not improve from 0.06199
#
# Epoch 00370: val_loss did not improve from 0.06199
#
# Epoch 00371: val_loss did not improve from 0.06199
#
# Epoch 00372: val_loss did not improve from 0.06199
#
# Epoch 00373: val_loss did not improve from 0.06199
#
# Epoch 00374: val_loss did not improve from 0.06199
#
# Epoch 00375: val_loss did not improve from 0.06199
#
# Epoch 00376: val_loss did not improve from 0.06199
#
# Epoch 00377: val_loss did not improve from 0.06199
#
# Epoch 00378: val_loss did not improve from 0.06199
#
# Epoch 00379: val_loss did not improve from 0.06199
#
# Epoch 00380: val_loss did not improve from 0.06199
#
# Epoch 00381: val_loss did not improve from 0.06199
#
# Epoch 00382: val_loss did not improve from 0.06199
#
# Epoch 00383: val_loss did not improve from 0.06199
#
# Epoch 00384: val_loss did not improve from 0.06199
#
# Epoch 00385: val_loss did not improve from 0.06199
#
# Epoch 00386: val_loss did not improve from 0.06199
#
# Epoch 00387: val_loss did not improve from 0.06199
#
# Epoch 00388: val_loss did not improve from 0.06199
#
# Epoch 00389: val_loss did not improve from 0.06199
#
# Epoch 00390: val_loss did not improve from 0.06199
#
# Epoch 00391: val_loss did not improve from 0.06199
#
# Epoch 00392: val_loss did not improve from 0.06199
#
# Epoch 00393: val_loss did not improve from 0.06199
#
# Epoch 00394: val_loss did not improve from 0.06199
#
# Epoch 00395: val_loss did not improve from 0.06199
#
# Epoch 00396: val_loss did not improve from 0.06199
#
# Epoch 00397: val_loss did not improve from 0.06199
#
# Epoch 00398: val_loss did not improve from 0.06199
#
# Epoch 00399: val_loss improved from 0.06199 to 0.06196, saving model to ./model/final399-0.0620.hdf5
#
# Epoch 00400: val_loss did not improve from 0.06196
#
# Epoch 00401: val_loss did not improve from 0.06196
#
# Epoch 00402: val_loss did not improve from 0.06196
#
# Epoch 00403: val_loss did not improve from 0.06196
#
# Epoch 00404: val_loss did not improve from 0.06196
#
# Epoch 00405: val_loss did not improve from 0.06196
#
# Epoch 00406: val_loss did not improve from 0.06196
#
# Epoch 00407: val_loss did not improve from 0.06196
#
# Epoch 00408: val_loss did not improve from 0.06196
#
# Epoch 00409: val_loss did not improve from 0.06196
#
# Epoch 00410: val_loss did not improve from 0.06196
#
# Epoch 00411: val_loss did not improve from 0.06196
#
# Epoch 00412: val_loss did not improve from 0.06196
#
# Epoch 00413: val_loss did not improve from 0.06196
#
# Epoch 00414: val_loss did not improve from 0.06196
#
# Epoch 00415: val_loss did not improve from 0.06196
#
# Epoch 00416: val_loss did not improve from 0.06196
#
# Epoch 00417: val_loss did not improve from 0.06196
#
# Epoch 00418: val_loss did not improve from 0.06196
#
# Epoch 00419: val_loss did not improve from 0.06196
#
# Epoch 00420: val_loss did not improve from 0.06196
#
# Epoch 00421: val_loss did not improve from 0.06196
#
# Epoch 00422: val_loss did not improve from 0.06196
#
# Epoch 00423: val_loss did not improve from 0.06196
#
# Epoch 00424: val_loss did not improve from 0.06196
#
# Epoch 00425: val_loss did not improve from 0.06196
#
# Epoch 00426: val_loss did not improve from 0.06196
#
# Epoch 00427: val_loss did not improve from 0.06196
#
# Epoch 00428: val_loss did not improve from 0.06196
#
# Epoch 00429: val_loss did not improve from 0.06196
#
# Epoch 00430: val_loss did not improve from 0.06196
#
# Epoch 00431: val_loss did not improve from 0.06196
#
# Epoch 00432: val_loss did not improve from 0.06196
#
# Epoch 00433: val_loss did not improve from 0.06196
#
# Epoch 00434: val_loss did not improve from 0.06196
#
# Epoch 00435: val_loss did not improve from 0.06196
#
# Epoch 00436: val_loss did not improve from 0.06196
#
# Epoch 00437: val_loss did not improve from 0.06196
#
# Epoch 00438: val_loss did not improve from 0.06196
#
# Epoch 00439: val_loss did not improve from 0.06196
#
# Epoch 00440: val_loss did not improve from 0.06196
#
# Epoch 00441: val_loss did not improve from 0.06196
#
# Epoch 00442: val_loss did not improve from 0.06196
#
# Epoch 00443: val_loss did not improve from 0.06196
#
# Epoch 00444: val_loss did not improve from 0.06196
#
# Epoch 00445: val_loss did not improve from 0.06196
#
# Epoch 00446: val_loss did not improve from 0.06196
#
# Epoch 00447: val_loss did not improve from 0.06196
#
# Epoch 00448: val_loss did not improve from 0.06196
#
# Epoch 00449: val_loss did not improve from 0.06196
#
# Epoch 00450: val_loss did not improve from 0.06196
#
# Epoch 00451: val_loss did not improve from 0.06196
#
# Epoch 00452: val_loss did not improve from 0.06196
#
# Epoch 00453: val_loss did not improve from 0.06196
#
# Epoch 00454: val_loss did not improve from 0.06196
#
# Epoch 00455: val_loss did not improve from 0.06196
#
# Epoch 00456: val_loss did not improve from 0.06196
#
# Epoch 00457: val_loss did not improve from 0.06196
#
# Epoch 00458: val_loss did not improve from 0.06196
#
# Epoch 00459: val_loss did not improve from 0.06196
#
# Epoch 00460: val_loss did not improve from 0.06196
#
# Epoch 00461: val_loss did not improve from 0.06196
#
# Epoch 00462: val_loss did not improve from 0.06196
#
# Epoch 00463: val_loss did not improve from 0.06196
#
# Epoch 00464: val_loss did not improve from 0.06196
#
# Epoch 00465: val_loss did not improve from 0.06196
#
# Epoch 00466: val_loss did not improve from 0.06196
#
# Epoch 00467: val_loss did not improve from 0.06196
#
# Epoch 00468: val_loss did not improve from 0.06196
#
# Epoch 00469: val_loss did not improve from 0.06196
#
# Epoch 00470: val_loss did not improve from 0.06196
#
# Epoch 00471: val_loss did not improve from 0.06196
#
# Epoch 00472: val_loss did not improve from 0.06196
#
# Epoch 00473: val_loss did not improve from 0.06196
#
# Epoch 00474: val_loss did not improve from 0.06196
#
# Epoch 00475: val_loss did not improve from 0.06196
#
# Epoch 00476: val_loss did not improve from 0.06196
#
# Epoch 00477: val_loss did not improve from 0.06196
#
# Epoch 00478: val_loss did not improve from 0.06196
#
# Epoch 00479: val_loss did not improve from 0.06196
#
# Epoch 00480: val_loss did not improve from 0.06196
#
# Epoch 00481: val_loss did not improve from 0.06196
#
# Epoch 00482: val_loss did not improve from 0.06196
#
# Epoch 00483: val_loss did not improve from 0.06196
# Epoch 00484: val_loss did not improve from 0.06196
#
# Epoch 00485: val_loss did not improve from 0.06196
#
# Epoch 00486: val_loss did not improve from 0.06196
#
# Epoch 00487: val_loss did not improve from 0.06196
#
# Epoch 00488: val_loss did not improve from 0.06196
#
# Epoch 00489: val_loss did not improve from 0.06196
#
# Epoch 00490: val_loss did not improve from 0.06196
#
# Epoch 00491: val_loss did not improve from 0.06196
#
# Epoch 00492: val_loss did not improve from 0.06196
#
# Epoch 00493: val_loss did not improve from 0.06196
#
# Epoch 00494: val_loss did not improve from 0.06196
#
# Epoch 00495: val_loss did not improve from 0.06196
#
# Epoch 00496: val_loss did not improve from 0.06196
#
# Epoch 00497: val_loss did not improve from 0.06196
#
# Epoch 00498: val_loss did not improve from 0.06196
#
# Epoch 00499: val_loss did not improve from 0.06196

# %%
# del model
model = load_model('model/final399-0.0620.hdf5')
print("\n Accuracy: %.4f" % (model.evaluate(X, Y, verbose=2)[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-49931d476191> in <module>
#       1 # del model
#       2 model = load_model('model/final399-0.0620.hdf5')
# ----> 3 print("\n Accuracy: %.4f" % (model.evaluate(X, Y, verbose=2)[1]))
#
# NameError: name 'X' is not defined

# %%
# y_vloss에 테스트셋으로 실험 결과의 오차 값을 저장
y_vloss=history.history['val_loss']

# %%
# y_acc에 학습셋으로 측정한 정확도의 값을 저장
y_acc=history.history['accuracy']

# %%
# x 값을 지정하고 정확도를 파란색으로, 오차를 빨간색으로 표시
x_len = np.arange(len(y_acc))
plt.figure(figsize=(12,6))
plt.plot(x_len, y_vloss, "o", c="red", markersize=2)
plt.plot(x_len, y_acc, "o", c="blue", markersize=2)

plt.show()
