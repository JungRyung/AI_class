# %%
from urllib import request as url
import re
from collections import Counter

def wordcount(url_input):
    with url.urlopen(url_input)as doc:
        #decode 헥사코드를 변환
        html = doc.read().decode()
        words = re.findall(r'\w+',html)
        
        frequency = Counter(words).most_common()
        
        
    return frequency

# %%
if __name__ == '__main__':
    result = wordcount('http://www.daum.net/')

# %%
result
# Out:
# [('class', 1080),
#  ('data', 839),
#  ('span', 757),
#  ('tiara', 681),
#  ('0', 646),
#  ('position', 544),
#  ('height', 542),
#  ('background', 524),
#  ('a', 453),
#  ('net', 450),
#  ('width', 419),
#  ('top', 366),
#  ('li', 343),
#  ('div', 295),
#  ('layer', 281),
#  ('left', 278),
#  ('action', 277),
#  ('daumcdn', 272),
#  ('href', 240),
#  ('hidden', 240),
#  ('name', 236),
#  ('margin', 236),
#  ('color', 218),
#  ('padding', 216),
#  ('https', 209),
#  ('t1', 208),
#  ('overflow', 206),
#  ('font', 197),
#  ('daum', 181),
#  ('right', 171),
#  ('display', 169),
#  ('os_mac', 166),
#  ('id', 162),
#  ('text', 158),
#  ('line', 155),
#  ('size', 154),
#  ('png', 144),
#  ('src', 142),
#  ('block', 139),
#  ('daumtop_deco', 136),
#  ('images', 135),
#  ('strong', 131),
#  ('1px', 118),
#  ('absolute', 116),
#  ('float', 116),
#  ('frame_g', 114),
#  ('url', 110),
#  ('img', 104),
#  ('suggestBox', 100),
#  ('keyboard_layer', 89),
#  ('link_tit', 84),
#  ('bottom', 81),
#  ('today_layer', 81),
#  ('12px', 79),
#  ('dd', 77),
#  ('none', 77),
#  ('relative', 77),
#  ('img_thumb', 77),
#  ('op', 76),
#  ('v', 76),
#  ('border', 74),
#  ('screen_out', 74),
#  ('em', 73),
#  ('http', 72),
#  ('align', 72),
#  ('ir_wa', 72),
#  ('alt', 72),
#  ('20px', 70),
#  ('16px', 69),
#  ('amp', 69),
#  ('view_slide', 68),
#  ('thumb', 68),
#  ('13px', 67),
#  ('tit_item', 66),
#  ('2017', 64),
#  ('cont_item', 64),
#  ('link_thumb', 63),
#  ('true', 62),
#  ('11px', 60),
#  ('14px', 60),
#  ('100', 59),
#  ('30px', 58),
#  ('suggest_exact', 58),
#  ('search', 57),
#  ('1', 57),
#  ('link_item', 57),
#  ('aria', 57),
#  ('transform', 56),
#  ('kind', 56),
#  ('ClickContent', 56),
#  ('ordnum', 56),
#  ('img2', 56),
#  ('fname', 56),
#  ('ico_pctop', 55),
#  ('solid', 54),
#  ('2px', 54),
#  ('panel_bloc', 54),
#  ('h3', 53),
#  ('hover', 52),
#  ('webtoon', 52),
#  ('10px', 51),
#  ('10', 50),
#  ('repeat', 49),
#  ('group_keyboard', 49),
#  ('39', 49),
#  ('news', 47),
#  ('button', 46),
#  ('thumb_g', 46),
#  ('15px', 46),
#  ('default', 46),
#  ('EC', 46),
#  ('fff', 45),
#  ('decoration', 45),
#  ('index', 45),
#  ('info_today', 45),
#  ('8px', 44),
#  ('com', 44),
#  ('title', 43),
#  ('vertical', 43),
#  ('inline', 43),
#  ('space', 43),
#  ('white', 42),
#  ('888', 42),
#  ('target', 42),
#  ('image', 41),
#  ('jpg', 41),
#  ('ul', 40),
#  ('indent', 40),
#  ('txt_pctop', 40),
#  ('18px', 40),
#  ('fst', 40),
#  ('클릭', 40),
#  ('GNB_서비스_더보기', 40),
#  ('_blank', 39),
#  ('no', 38),
#  ('nowrap', 38),
#  ('레이어_서비스', 38),
#  ('hamny', 38),
#  ('weight', 37),
#  ('4px', 37),
#  ('7px', 37),
#  ('link_svc', 37),
#  ('relay_special', 37),
#  ('type', 36),
#  ('z', 36),
#  ('9px', 36),
#  ('auto', 35),
#  ('94', 35),
#  ('p', 34),
#  ('family', 34),
#  ('sans', 34),
#  ('serif', 34),
#  ('36px', 34),
#  ('60px', 34),
#  ('60', 34),
#  ('kakao', 34),
#  ('letter', 33),
#  ('spacing', 33),
#  ('9999px', 33),
#  ('3px', 33),
#  ('gallery', 33),
#  ('ellipsis', 32),
#  ('img_weather', 31),
#  ('media', 31),
#  ('154', 31),
#  ('5px', 30),
#  ('origin_item', 30),
#  ('translateY', 30),
#  ('viewer', 30),
#  ('202006', 30),
#  ('normal', 29),
#  ('hide', 29),
#  ('transition', 29),
#  ('max', 29),
#  ('view_photo', 29),
#  ('q', 28),
#  ('foot_daum', 28),
#  ('6px', 28),
#  ('100px', 28),
#  ('wrap_tabcont', 28),
#  ('오늘의', 28),
#  ('h2', 27),
#  ('list_ranking', 27),
#  ('날씨', 27),
#  ('dt', 26),
#  ('40px', 26),
#  ('on', 26),
#  ('tit_tabcont', 26),
#  ('EB', 26),
#  ('소재', 26),
#  ('118eff', 25),
#  ('28px', 25),
#  ('btn_keyboard', 25),
#  ('22px', 25),
#  ('ico_degree', 25),
#  ('list_relay', 25),
#  ('rtn', 25),
#  ('카카오', 25),
#  ('dl', 24),
#  ('ico_vert', 24),
#  ('120px', 24),
#  ('17px', 24),
#  ('night', 24),
#  ('service_layer', 24),
#  ('txt_temper', 24),
#  ('word', 24),
#  ('box_channel', 24),
#  ('tot', 24),
#  ('w', 24),
#  ('DA', 24),
#  ('tv', 24),
#  ('page_pctop', 23),
#  ('login_my', 23),
#  ('영상', 23),
#  ('45px', 22),
#  ('ico_ws', 22),
#  ('txt', 22),
#  ('ececec', 21),
#  ('80px', 21),
#  ('txt_part', 21),
#  ('포토_데이터', 21),
#  ('center', 20),
#  ('sort_service', 20),
#  ('break', 20),
#  ('ad', 20),
#  ('C', 20),
#  ('num_pctop', 19),
#  ('head_daum', 19),
#  ('200px', 19),
#  ('btn_page', 19),
#  ('154px', 19),
#  ('list_story', 19),
#  ('list_wtrank', 19),
#  ('box_photo', 19),
#  ('tabindex', 19),
#  ('imp_id', 19),
#  ('custom', 19),
#  ('c_id', 19),
#  ('script', 18),
#  ('style', 18),
#  ('222', 18),
#  ('shortcut_g', 18),
#  ('300px', 18),
#  ('19px', 18),
#  ('555', 18),
#  ('ico_video', 18),
#  ('list_thumb', 18),
#  ('cover_g', 18),
#  ('relay_general', 18),
#  ('box_chextra', 18),
#  ('box_infobnr', 18),
#  ('9C', 18),
#  ('date', 18),
#  ('운영_하단', 18),
#  ('h4', 17),
#  ('26px', 17),
#  ('24px', 17),
#  ('list_mainsvc', 17),
#  ('btn_next', 17),
#  ('link_txt', 17),
#  ('159px', 17),
#  ('list_music', 17),
#  ('2', 17),
#  ('ED', 17),
#  ('2020', 17),
#  ('content', 16),
#  ('underline', 16),
#  ('34px', 16),
#  ('0px', 16),
#  ('link_favorsch', 16),
#  ('arial', 16),
#  ('25px', 16),
#  ('info_temper', 16),
#  ('310px', 16),
#  ('list_txt', 16),
#  ('link_home', 16),
#  ('lst', 16),
#  ('06', 16),
#  ('탭', 16),
#  ('S308x188', 16),
#  ('동영상', 16),
#  ('cp', 16),
#  ('noimg_1x1', 16),
#  ('S700x400', 16),
#  ('400', 16),
#  ('썸네일', 16),
#  ('thumbnail', 16),
#  ('S60x60', 16),
#  ('min', 15),
#  ('webkit', 15),
#  ('link_info', 15),
#  ('150px', 15),
#  ('166px', 15),
#  ('list_mysvc', 15),
#  ('70px', 15),
#  ('link_ranking', 15),
#  ('box_special', 15),
#  ('topic_type2', 15),
#  ('3s', 15),
#  ('ease', 15),
#  ('3', 15),
#  ('뉴스1탭_텍스트소재', 15),
#  ('8', 14),
#  ('pointer', 14),
#  ('990px', 14),
#  ('68px', 14),
#  ('260px', 14),
#  ('inner_login', 14),
#  ('152px', 14),
#  ('link_sector', 14),
#  ('txt_ranking', 14),
#  ('o', 14),
#  ('12', 14),
#  ('B0', 14),
#  ('95', 14),
#  ('tab', 14),
#  ('day', 14),
#  ('www', 13),
#  ('input', 13),
#  ('ms', 13),
#  ('transparent', 13),
#  ('inner_shortcut', 13),
#  ('32px', 13),
#  ('box_search', 13),
#  ('bold', 13),
#  ('21px', 13),
#  ('90px', 13),
#  ('333', 13),
#  ('130px', 13),
#  ('daumtop_chanel', 13),
#  ('버튼', 13),
#  ('section', 13),
#  ('oc', 13),
#  ('카테고리', 13),
#  ('active', 12),
#  ('btn_close', 12),
#  ('102px', 12),
#  ('link_weather', 12),
#  ('list_basis', 12),
#  ('ico_label2', 12),
#  ('unit_home', 12),
#  ('list_newslive', 12),
#  ('346px', 12),
#  ('box_best', 12),
#  ('moz', 12),
#  ('84', 12),
#  ('4', 12),
#  ('quot', 12),
#  ('스토리', 12),
#  ('cate', 12),
#  ('rel', 11),
#  ('cursor', 11),
#  ('opacity', 11),
#  ('37px', 11),
#  ('item', 11),
#  ('footer', 11),
#  ('23px', 11),
#  ('box_story', 11),
#  ('ntype_img', 11),
#  ('tit_info', 11),
#  ('box_chwide', 11),
#  ('바로가기', 11),
#  ('EA', 11),
#  ('98', 11),
#  ('news1탭_게이트영역_게이트클릭', 11),
#  ('view', 11),
#  ('meta', 10),
#  ('다음', 10),
#  ('javascript', 10),
#  ('clear', 10),
#  ('33px', 10),
#  ('2019', 10),
#  ('78px', 10),
#  ('txt_dot', 10),
#  ('240px', 10),
#  ('ico_wm03', 10),
#  ('login_master', 10),
#  ('info_page', 10),
#  ('page_btype', 10),
#  ('170px', 10),
#  ('tit_subject', 10),
#  ('opt_dropdown', 10),
#  ('txt_info', 10),
#  ('list_movie3', 10),
#  ('list_series', 10),
#  ('type_img', 10),
#  ('out', 10),
#  ('tistory', 10),
#  ('middot', 10),
#  ('html', 9),
#  ('js', 9),
#  ('after', 9),
#  ('d_index', 9),
#  ('50', 9),
#  ('both', 9),
#  ('31px', 9),
#  ('180px', 9),
#  ('44px', 9),
#  ('140px', 9),
#  ('coll_svc', 9),
#  ('160px', 9),
#  ('info_wm', 9),
#  ('table', 9),
#  ('6', 9),
#  ('all', 9),
#  ('321px', 9),
#  ('box_issue', 9),
#  ('ranking_news', 9),
#  ('list_special', 9),
#  ('cont_info', 9),
#  ('list_movie1', 9),
#  ('157px', 9),
#  ('list_chbest', 9),
#  ('group_recomm', 9),
#  ('best_img', 9),
#  ('link_photo', 9),
#  ('list_thumbnail', 9),
#  ('vphoto_type2', 9),
#  ('list_thumbnail3', 9),
#  ('list_thumbnail4', 9),
#  ('list_thumbnail5', 9),
#  ('list_thumbnail7', 9),
#  ('list_thumbnail8', 9),
#  ('bookmark', 9),
#  ('포토', 9),
#  ('B8', 9),
#  ('NPI', 9),
#  ('kakaotv', 9),
#  ('game', 9),
#  ('charset', 8),
#  ('utf', 8),
#  ('before', 8),
#  ('5', 8),
#  ('Gothic', 8),
#  ('220px', 8),
#  ('list_favorsch', 8),
#  ('210px', 8),
#  ('tahoma', 8),
#  ('59px', 8),
#  ('layer_foot', 8),
#  ('link_login', 8),
#  ('txt_mark', 8),
#  ('info_special', 8),
#  ('list_auto', 8),
#  ('list_realestate', 8),
#  ('type_desc', 8),
#  ('graph_item', 8),
#  ('section_channel', 8),
#  ('wrap_together', 8),
#  ('btn_preview', 8),
#  ('txt_gallery', 8),
#  ('inner_notice_layer', 8),
#  ('mobileweb_layer', 8),
#  ('431px', 8),
#  ('DT', 8),
#  ('AC', 8),
#  ('88', 8),
#  ('map', 8),
#  ('brunch', 8),
#  ('story', 8),
#  ('entertain', 8),
#  ('비', 8),
#  ('ins', 8),
#  ('newsbox', 8),
#  ('C308x188', 8),
#  ('NEWS1', 8),
#  ('property', 7),
#  ('middle', 7),
#  ('49px', 7),
#  ('29px', 7),
#  ('eng_basic', 7),
#  ('eng_shift', 7),
#  ('dcdcdc', 7),
#  ('txt_exact', 7),
#  ('num1', 7),
#  ('108px', 7),
#  ('today_base', 7),
#  ('ico_wm04', 7),
#  ('ico_wm09', 7),
#  ('298px', 7),
#  ('400px', 7),
#  ('state_desc', 7),
#  ('ico_label', 7),
#  ('wrap', 7),
#  ('section_media', 7),
#  ('special_issue', 7),
#  ('item_station', 7),
#  ('cast_sports', 7),
#  ('info_game', 7),
#  ('tit_name', 7),
#  ('info_game2', 7),
#  ('type_chdesc', 7),
#  ('box_music', 7),
#  ('wrap_topic', 7),
#  ('inner_browser_layer', 7),
#  ('list_hotissue', 7),
#  ('정보', 7),
#  ('role', 7),
#  ('이전', 7),
#  ('cafe', 7),
#  ('뉴스', 7),
#  ('together', 7),
#  ('wed', 7),
#  ('small', 7),
#  ('Daum', 6),
#  ('uri', 6),
#  ('body', 6),
#  ('ol', 6),
#  ('radius', 6),
#  ('ico_pctop2', 6),
#  ('bg_pctop_190612', 6),
#  ('35px', 6),
#  ('50px', 6),
#  ('linear', 6),
#  ('42px', 6),
#  ('58px', 6),
#  ('kor_basic', 6),
#  ('kor_shift', 6),
#  ('270px', 6),
#  ('keyboard_spe', 6),
#  ('baseBox', 6),
#  ('Apple', 6),
#  ('SD', 6),
#  ('Neo', 6),
#  ('fbfbfb', 6),
#  ('static', 6),
#  ('ico_new', 6),
#  ('ico_wm02', 6),
#  ('num2', 6),
#  ('num3', 6),
#  ('148px', 6),
#  ('43px', 6),
#  ('link_user', 6),
#  ('cafe_g', 6),
#  ('110px', 6),
#  ('keep', 6),
#  ('319px', 6),
#  ('17', 6),
#  ('9', 6),
#  ('link_station', 6),
#  ('game_play', 6),
#  ('vs_team1', 6),
#  ('list_movie2', 6),
#  ('tab_multi', 6),
#  ('bar_support', 6),
#  ('thumb_channel', 6),
#  ('box_recomm', 6),
#  ('list_recomm', 6),
#  ('head_item', 6),
#  ('btn_prev', 6),
#  ('rtmaxcoll', 6),
#  ('NNS', 6),
#  ('NPT', 6),
#  ('82', 6),
#  ('preBtn', 6),
#  ('nextBtn', 6),
#  ('sports', 6),
#  ('26도', 6),
#  ('26', 6),
#  ('구름많음', 6),
#  ('channel', 6),
#  ('웹툰_이미지', 6),
#  ('랭킹_소재', 6),
#  ('premium', 6),
#  ('og', 5),
#  ('ico', 5),
#  ('mail', 5),
#  ('list', 5),
#  ('dotum', 5),
#  ('돋움', 5),
#  ('filter', 5),
#  ('250px', 5),
#  ('list_notice', 5),
#  ('tf_keyword', 5),
#  ('info_policy', 5),
#  ('39px', 5),
#  ('46px', 5),
#  ('135px', 5),
#  ('56px', 5),
#  ('136px', 5),
#  ('search1', 5),
#  ('statics', 5),
#  ('common', 5),
#  ('pi', 5),
#  ('gif', 5),
#  ('600px', 5),
#  ('48px', 5),
#  ('layer_body', 5),
#  ('sort_type2', 5),
#  ('146px', 5),
#  ('helvetica', 5),
#  ('ico_wm10', 5),
#  ('login_tmp', 5),
#  ('layer_sso', 5),
#  ('11', 5),
#  ('72px', 5),
#  ('link_mysvc', 5),
#  ('txt_slash', 5),
#  ('94px', 5),
#  ('split_part', 5),
#  ('link_smore', 5),
#  ('ico_arrow', 5),
#  ('57px', 5),
#  ('link_special', 5),
#  ('list_item', 5),
#  ('box_newslive', 5),
#  ('img_station', 5),
#  ('txt_league', 5),
#  ('num_score', 5),
#  ('txt_status', 5),
#  ('txt_team', 5),
#  ('num_index', 5),
#  ('box_imgspe', 5),
#  ('256px', 5),
#  ('96px', 5),
#  ('398px', 5),
#  ('link_channel', 5),
#  ('tit_photo', 5),
#  ('detail_photo', 5),
#  ('0s', 5),
#  ('hotissue_mini', 5),
#  ('initial', 5),
#  ('important', 5),
#  ('translateX', 5),
#  ('new', 5),
#  ('kas', 5),
#  ('서비스', 5),
#  ('false', 5),
#  ('9D', 5),
#  ('B4', 5),
#  ('A0', 5),
#  ('A7', 5),
#  ('제주', 5),
#  ('lt', 5),
#  ('gt', 5),
#  ('dic', 5),
#  ('전체', 5),
#  ('스포츠', 5),
#  ('movie', 5),
#  ('kakaocorp', 5),
#  ('흐림', 5),
#  ('현재', 5),
#  ('2F', 5),
#  ('newslink', 5),
#  ('14', 5),
#  ('ranking', 5),
#  ('tvpot', 5),
#  ('16', 5),
#  ('policy', 5),
#  ('fieldset', 4),
#  ('textarea', 4),
#  ('blockquote', 4),
#  ('select', 4),
#  ('ico_top_layer', 4),
#  ('08', 4),
#  ('alpha', 4),
#  ('fbfbfc', 4),
#  ('link_notice', 4),
#  ('0089ff', 4),
#  ('txt_copyright', 4),
#  ('inner_search', 4),
#  ('480px', 4),
#  ('굴림', 4),
#  ('gulim', 4),
#  ('27px', 4),
#  ('txt_time', 4),
#  ('weather', 4),
#  ('66px', 4),
#  ('212px', 4),
#  ('109px', 4),
#  ('tit_split', 4),
#  ('ico_more', 4),
#  ('ico_wm01', 4),
#  ('ico_wm05', 4),
#  ('ico_wm06', 4),
#  ('ico_wm13', 4),
#  ('ico_wm16', 4),
#  ('txt_place', 4),
#  ('500px', 4),
#  ('box_shopping', 4),
#  ('advert_bnr', 4),
#  ('99', 4),
#  ('name_user', 4),
#  ('cell', 4),
#  ('54px', 4),
#  ('txt_mysvc', 4),
#  ('62px', 4),
#  ('ico_label3', 4),
#  ('page_tabcont', 4),
#  ('part_mid', 4),
#  ('list_stxt', 4),
#  ('tit_news', 4),
#  ('tit_entertain', 4),
#  ('tit_sports', 4),
#  ('tit_movie', 4),
#  ('tit_auto', 4),
#  ('tit_realestate', 4),
#  ('news_prime', 4),
#  ('box_sector', 4),
#  ('news_flow', 4),
#  ('tit_home', 4),
#  ('list_home', 4),
#  ('unit_live', 4),
#  ('list_rgate', 4),
#  ('93px', 4),
#  ('box', 4),
#  ('data_name', 4),
#  ('vs_team2', 4),
#  ('num_g', 4),
#  ('section_blog', 4),
#  ('tit_cafe', 4),
#  ('tit_brunch', 4),
#  ('tit_tistory', 4),
#  ('tit_ilboonnews', 4),
#  ('tit_kakaostory', 4),
#  ('c9c9c9', 4),
#  ('tit_homecooking', 4),
#  ('tit_money', 4),
#  ('tit_pet', 4),
#  ('tit_women', 4),
#  ('tit_men', 4),
#  ('tit_travel', 4),
#  ('tit_business', 4),
#  ('tit_music', 4),
#  ('tit_webtoon', 4),
#  ('tit_game', 4),
#  ('tit_together', 4),
#  ('channel_item', 4),
#  ('box_wtrank', 4),
#  ('list_photo', 4),
#  ('btn_move', 4),
#  ('topic_spe', 4),
#  ('link_gate2', 4),
#  ('topicbg_wing', 4),
#  ('txt_mobile', 4),
#  ('only', 4),
#  ('screen', 4),
#  ('and', 4),
#  ('cEtc', 4),
#  ('document', 4),
#  ('function', 4),
#  ('블로그', 4),
#  ('쇼핑', 4),
#  ('doc', 4),
#  ('top_accessibility', 4),
#  ('검색', 4),
#  ('A6', 4),
#  ('7', 4),
#  ('80', 4),
#  ('B2', 4),
#  ('BC', 4),
#  ('blog', 4),
#  ('more', 4),
#  ('kakao_ad_area', 4),
#  ('frame', 4),
#  ('unit', 4),
#  ('DAN', 4),
#  ('ba', 4),
#  ('뉴스1탭_이미지소재', 4),
#  ('뉴스1탭_생중계', 4),
#  ('mtop', 4),
#  ('m640', 4),
#  ('15', 4),
#  ('TMZ', 4),
#  ('cont_multi', 4),
#  ('video', 4),
#  ('tv_1tab_이미지', 4),
#  ('cliplink', 4),
#  ('tv_2tab_이미지', 4),
#  ('tv_3tab_이미지', 4),
#  ('tv_4tab_이미지', 4),
#  ('tstory', 4),
#  ('영역_3tab_이미지', 4),
#  ('by', 4),
#  ('business', 4),
#  ('웹툰_연재', 4),
#  ('웹툰_완결', 4),
#  ('300', 4),
#  ('05', 4),
#  ('sportsdonga', 4),
#  ('체크', 4),
#  ('뉴스1', 4),
#  ('보기', 4),
#  ('svc', 3),
#  ('msapplication', 3),
#  ('task', 3),
#  ('icon', 3),
#  ('메일', 3),
#  ('h1', 3),
#  ('form', 3),
#  ('legend', 3),
#  ('th', 3),
#  ('td', 3),
#  ('var', 3),
#  ('223px', 3),
#  ('ico_pctop_vert_170724', 3),
#  ('ico_vert2', 3),
#  ('daumWrap', 3),
#  ('1080px', 3),
#  ('wrap_main', 3),
#  ('visibility', 3),
#  ('655px', 3),
#  ('info_notice', 3),
#  ('209px', 3),
#  ('btn_search', 3),
#  ('230px', 3),
#  ('link_svcall', 3),
#  ('y', 3),
#  ('d_head', 3),
#  ('link_launch', 3),
#  ('wrap_search', 3),
#  ('head_bnr', 3),
#  ('img_keyboard', 3),
#  ('btn_key', 3),
#  ('tit_keyboard', 3),
#  ('330px', 3),
#  ('360px', 3),
#  ('75px', 3),
#  ('105px', 3),
#  ('195px', 3),
#  ('345px', 3),
#  ('41px', 3),
#  ('71px', 3),
#  ('daumSuggestWrap', 3),
#  ('ededed', 3),
#  ('bar', 3),
#  ('cont', 3),
#  ('wrap_today', 3),
#  ('txt_num', 3),
#  ('ico_suggest', 3),
#  ('d_service', 3),
#  ('menu_service', 3),
#  ('link_more', 3),
#  ('139px', 3),
#  ('176px', 3),
#  ('47px', 3),
#  ('bg_line', 3),
#  ('link_total', 3),
#  ('date_today', 3),
#  ('list_weather', 3),
#  ('138px', 3),
#  ('292px', 3),
#  ('ico_wm', 3),
#  ('700px', 3),
#  ('800px', 3),
#  ('num4', 3),
#  ('num5', 3),
#  ('280px', 3),
#  ('320px', 3),
#  ('txt_desc', 3),
#  ('link_state', 3),
#  ('ico_dust', 3),
#  ('ico_air', 3),
#  ('advert_tmp', 3),
#  ('advert_station', 3),
#  ('advert_svcbnr', 3),
#  ('wrap_tiercont', 3),
#  ('bg_login', 3),
#  ('link_join', 3),
#  ('link_kakaoid', 3),
#  ('thumb_profile', 3),
#  ('layer_mycont', 3),
#  ('92px', 3),
#  ('split_txt', 3),
#  ('122px', 3),
#  ('news_on', 3),
#  ('link_relay', 3),
#  ('Helvetica', 3),
#  ('info_status', 3),
#  ('link_view', 3),
#  ('box_cell', 3),
#  ('f5f5f5', 3),
#  ('info_empty', 3),
#  ('info_team', 3),
#  ('game_empty', 3),
#  ('btn_select', 3),
#  ('link_option', 3),
#  ('section_multi', 3),
#  ('tit_kakaotv', 3),
#  ('kakaotv_on', 3),
#  ('wrap_kakaotv', 3),
#  ('tistory_on', 3),
#  ('106px', 3),
#  ('info_graph', 3),
#  ('full_graph', 3),
#  ('133px', 3),
#  ('182px', 3),
#  ('274px', 3),
#  ('325px', 3),
#  ('362px', 3),
#  ('tit_together2', 3),
#  ('434px', 3),
#  ('webtoon_on', 3),
#  ('together_on', 3),
#  ('124px', 3),
#  ('295px', 3),
#  ('events', 3),
#  ('tit_gallery', 3),
#  ('desc_source', 3),
#  ('190px', 3),
#  ('list_thumbnail2', 3),
#  ('list_thumbnail6', 3),
#  ('610px', 3),
#  ('link_gate1', 3),
#  ('txt_sub2', 3),
#  ('link_mobile', 3),
#  ('roll_txt', 3),
#  ('current', 3),
#  ('return', 3),
#  ('미디어', 3),
#  ('이슈', 3),
#  ('value', 3),
#  ('searchbox', 3),
#  ('off', 3),
#  ('검색창_하단_인기검색어', 3),
#  ('B1', 3),
#  ('A1', 3),
#  ('A5', 3),
#  ('B6', 3),
#  ('BD', 3),
#  ('코로나19', 3),
#  ('81', 3),
#  ('A8', 3),
#  ('B3', 3),
#  ('카페', 3),
#  ('stock', 3),
#  ('카카오TV', 3),
#  ('co', 3),
#  ('kr', 3),
#  ('브런치', 3),
#  ('게임', 3),
#  ('같이가치', 3),
#  ('더보기', 3),
#  ('kakaostory', 3),
#  ('nil_profile', 3),
#  ('realestate', 3),
#  ('자동차', 3),
#  ('melon', 3),
#  ('jsp', 3),
#  ('sitemap', 3),
#  ('전체보기', 3),
#  ('28도', 3),
#  ('28', 3),
#  ('22', 3),
#  ('정보_클릭', 3),
#  ('P', 3),
#  ('로그인', 3),
#  ('accounts', 3),
#  ('3A', 3),
#  ('2Fwww', 3),
#  ('newsbox_news1', 3),
#  ('20200610175900541', 3),
#  ('20200610152034125', 3),
#  ('서예지', 3),
#  ('20200610162606144', 3),
#  ('20200610162915255', 3),
#  ('생중계', 3),
#  ('replay', 3),
#  ('20200610175754520', 3),
#  ('20200610174508103', 3),
#  ('20200610174548134', 3),
#  ('20200610174833228', 3),
#  ('20200610173100618', 3),
#  ('20200610164709978', 3),
#  ('20200610164801005', 3),
#  ('20200610173246671', 3),
#  ('20200610173334699', 3),
#  ('20200610173417728', 3),
#  ('20200610173723837', 3),
#  ('20200610174318033', 3),
#  ('20200610170655734', 3),
#  ('20200610171003836', 3),
#  ('20200610171054857', 3),
#  ('issue', 3),
#  ('series', 3),
#  ('랭킹', 3),
#  ('photo', 3),
#  ('TV하이라이트', 3),
#  ('추천', 3),
#  ('명장면', 3),
#  ('솔직하게', 3),
#  ('알려드립니다', 3),
#  ('ts', 3),
#  ('딸', 3),
#  ('리뷰', 3),
#  ('br', 3),
#  ('jcktPuh0lo', 3),
#  ('jEnQobh4pc', 3),
#  ('29', 3),
#  ('j7gsmcYdpe', 3),
#  ('20200610160920388', 3),
#  ('20200610150317303', 3),
#  ('20200610164912051', 3),
#  ('20200610174345040', 3),
#  ('20200610154411246', 3),
#  ('20200610113402621', 3),
#  ('20200610173645816', 3),
#  ('20200610161754745', 3),
#  ('20200610172044250', 3),
#  ('20200610161155481', 3),
#  ...]
