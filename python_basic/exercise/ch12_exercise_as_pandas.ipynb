# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
import matplotlib.font_manager as fm
import numpy as np
import pandas as pd

# # MacOS 한글 설정
from matplotlib import rc
rc('font', family='AppleGothic')
mpl.rcParams['axes.unicode_minus'] = False   # minus 표시

# Window 한글 설정
# from matplotlib import rc
# rc('font', family='D2Coding')
# mpl.rcParams['axes.unicode_minus'] = False   # minus 표시

# %%
df = pd.read_csv('cafe_2year.csv', skiprows=[0], names=['기준월','카페수'])
df
# Out:
#        기준월    카페수
# 0   201710  79296
# 1   201711  80738
# 2   201712  76923
# 3   201801  77942
# 4   201802  84967
# 5   201803  80719
# 6   201804  80719
# 7   201805  87156
# 8   201806  81248
# 9   201807  82191
# 10  201808  82858
# 11  201809  88742
# 12  201810  89050
# 13  201811  89661
# 14  201812  95650
# 15  201901  96352
# 16  201902  97009
# 17  201903  97415
# 18  201904  97421
# 19  201905  97740
# 20  201906  98217
# 21  201907  98311
# 22  201908  98538
# 23  201909  98779

# %%
df2 = df.iloc[2::3,:]
df2
# Out:
#        기준월    카페수
# 2   201712  76923
# 5   201803  80719
# 8   201806  81248
# 11  201809  88742
# 14  201812  95650
# 17  201903  97415
# 20  201906  98217
# 23  201909  98779

# %%
df2.plot.bar(x='기준월',y='카페수',ylim=[76923,98779])
plt.show()

# %%
df = pd.read_csv('doctor_2019.csv', skiprows=[0], names=['지역','병원명','일반의 수','인턴 수','레지던트 수','전문의 수'])
df
# Out:
#      지역           병원명  일반의 수  인턴 수  레지던트 수  전문의 수
# 0    인천  가톨릭대학교인천성모병원      1    22      68    201
# 1    서울        강북삼성병원      6    28     137    204
# 2    서울       건국대학교병원      1    37     164    225
# 3    대구       경북대학교병원      5    77     209    225
# 4    경남       경상대학교병원      1    35     114    182
# ..   ..           ...    ...   ...     ...    ...
# 350  서울          홍익병원      1     4      14     55
# 351  강원        홍천아산병원      1     0       0     10
# 352  경기  효산의료재단 안양샘병원      7     5      17     86
# 353  경기   효산의료재단 지샘병원      2     0       2     72
# 354  서울          희명병원      1     0       0     22
#
# [355 rows x 6 columns]

# %%
df2 = df.iloc[:,[0,2,3,4,5]]
df2
# Out:
#      지역  일반의 수  인턴 수  레지던트 수  전문의 수
# 0    인천      1    22      68    201
# 1    서울      6    28     137    204
# 2    서울      1    37     164    225
# 3    대구      5    77     209    225
# 4    경남      1    35     114    182
# ..   ..    ...   ...     ...    ...
# 350  서울      1     4      14     55
# 351  강원      1     0       0     10
# 352  경기      7     5      17     86
# 353  경기      2     0       2     72
# 354  서울      1     0       0     22
#
# [355 rows x 5 columns]

# %%
df3 = df2.groupby('지역').sum()
df3 = df3.loc[['서울','부산','대구','인천','대전','광주','울산'],:]
df3
# Out:
#     일반의 수  인턴 수  레지던트 수  전문의 수
# 지역
# 서울    162  1196    4757   9375
# 부산     58   197     785   2211
# 대구     27   215     712   1436
# 인천     47   138     444   1518
# 대전     25   142     425   1006
# 광주     16   102     356   1006
# 울산     19    23     104    467

# %%
df3.to_csv("doctor2.csv", mode='w')

# %%
df4 = pd.read_csv('doctor2.csv', skiprows=[0], names=['지역','일반의 수','인턴 수','레지던트 수','전문의 수'])
df4
# Out:
#    지역  일반의 수  인턴 수  레지던트 수  전문의 수
# 0  서울    162  1196    4757   9375
# 1  부산     58   197     785   2211
# 2  대구     27   215     712   1436
# 3  인천     47   138     444   1518
# 4  대전     25   142     425   1006
# 5  광주     16   102     356   1006
# 6  울산     19    23     104    467

# %%
df4.plot(kind='scatter',x='지역',y='레지던트 수')
plt.show()
