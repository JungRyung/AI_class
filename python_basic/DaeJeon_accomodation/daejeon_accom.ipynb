# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
import matplotlib.font_manager as fm
import numpy as np
import pandas as pd

# # MacOS 한글 설정
from matplotlib import rc
rc('font', family='AppleGothic')
mpl.rcParams['axes.unicode_minus'] = False   # minus 표시

# Window 한글 설정
# from matplotlib import rc
# rc('font', family='D2Coding')
# mpl.rcParams['axes.unicode_minus'] = False   # minus 표시

# %%
accom = pd.read_csv('숙박.csv',encoding = 'euc-kr')
accom
# Out:
#     연번            업소명                              업소소재지(도로명)  \
# 0    1           무명여관               대전광역시 서구 계룡로620번길 7 (용문동)
# 1    2           계룡여관                 대전광역시 서구 제비네3길 17 (도마동)
# 2    3          태양여인숙                 대전광역시 서구 제비네2길 84 (도마동)
# 3    4          스칼렛모텔              대전광역시 서구 도산로369번길 28 (용문동)
# 4    5          신온장여관                   대전광역시 서구 도산로 216 (변동)
# ..  ..            ...                                     ...
# 71  72   토요코인 대전정부청사앞     대전광역시 서구 둔산중로134번길 13, 15~18층 (둔산동)
# 72  73  주식회사 레지던스호텔힐링       대전광역시 서구 둔산로51번길 76, 2층~12층 (둔산동)
# 73  74           마치호텔       대전광역시 서구 둔산중로64번길 20, 2~12층 (둔산동)
# 74  75          그랜드캐슬  대전광역시 서구 문정로89번길 33, 그랜드캐슬 3~15층 (탄방동)
# 75  76       레지던스호텔라인       대전광역시 서구 둔산로51번길 76, 2층~12층 (둔산동)
#
#                        업소소재지(지번)       인허가일자  객실수  한실수  양실수
# 0       대전광역시 서구 용문동 589번지 4호     1980-02-13   15   12    3
# 1       대전광역시 서구 도마동 146번지 1호     1982-04-23   12   10    2
# 2      대전광역시 서구 도마동 128번지 47호     1982-02-15    8    8    0
# 3      대전광역시 서구 용문동 590번지 17호     1983-09-14   32    0   32
# 4        대전광역시 서구 변동 12번지 31호     1984-02-10   17    7   10
# ..                           ...         ...  ...  ...  ...
# 71   대전광역시 서구 둔산동 922번지  15~18층   2013-09-30   67    0   67
# 72  대전광역시 서구 둔산동 1351번지  2층~12층   2014-05-14   55    0   55
# 73  대전광역시 서구 둔산동 1466번지  2층~12층   2014-12-03  128    0  128
# 74    대전광역시 서구 탄방동 722번지  그랜드캐슬   2017-12-19  103    0  103
# 75        대전광역시 서구 둔산동 1351번지     2018-09-10   71    0   71
#
# [76 rows x 8 columns]

# %%
accom_sorted = accom.sort_values(by='객실수',ascending=True)
accom_sorted = accom_sorted.tail(20)
accom_sorted
# Out:
#     연번            업소명                              업소소재지(도로명)  \
# 34  35          모텔로데오               대전광역시 서구 둔산로31번길 34 (둔산동)
# 45  46           엠하우스             대전광역시 서구 월평로 53-10 (월평동,A동)
# 40  41          오백호모텔               대전광역시 서구 둔산로65번길 39 (둔산동)
# 38  39          모텔하우스             대전광역시 서구 대덕대로234번길 21 (둔산동)
# 65  66           호텔3월        대전광역시 서구 둔산중로32번길 29, 1~9층 (둔산동)
# 32  33          워커힐모텔                   대전광역시 서구 월평로 47 (월평동)
# 39  40          갤러리모텔               대전광역시 서구 둔산남로 98-16 (탄방동)
# 62  63        부띠크호텔락희             대전광역시 서구 대덕대로220번길 23 (둔산동)
# 52  53        휴앤유관광호텔          대전광역시 서구 한밭대로570번길 29-12 (월평동)
# 72  73  주식회사 레지던스호텔힐링       대전광역시 서구 둔산로51번길 76, 2층~12층 (둔산동)
# 43  44        디엠프레스호텔          대전광역시 서구 한밭대로570번길 29-20 (월평동)
# 71  72   토요코인 대전정부청사앞     대전광역시 서구 둔산중로134번길 13, 15~18층 (둔산동)
# 75  76       레지던스호텔라인       대전광역시 서구 둔산로51번길 76, 2층~12층 (둔산동)
# 74  75          그랜드캐슬  대전광역시 서구 문정로89번길 33, 그랜드캐슬 3~15층 (탄방동)
# 69  70    레지던스호텔 라 미아        대전광역시 서구 둔산로51번길 42, 2~10층 (둔산동)
# 73  74           마치호텔       대전광역시 서구 둔산중로64번길 20, 2~12층 (둔산동)
# 67  68       이안레지던스호텔        대전광역시 서구 둔산로65번길 29, 1~10층 (둔산동)
# 68  69  (주)굿모닝레지던스호텔휴        대전광역시 서구 둔산로73번길 21, 1~11층 (둔산동)
# 70  71       호텔그레이톤둔산          대전광역시 서구 둔산중로 70, 3층~15층 (둔산동)
# 63  64   토요코인 대전정부청사앞             대전광역시 서구 둔산중로134번길 13 (둔산동)
#
#                         업소소재지(지번)       인허가일자  객실수  한실수  양실수
# 34  대전광역시 서구 둔산동 1008번지 1호  5~8층   2001-03-05   45    4   41
# 45   대전광역시 서구 월평동 515번지  A동 3~7층   2002-09-25   45    3   42
# 40         대전광역시 서구 둔산동 1335번지     2002-02-01   46    4   42
# 38         대전광역시 서구 둔산동 1337번지     2001-11-22   46    8   38
# 65         대전광역시 서구 둔산동 1435번지     2016-05-20   49    0   49
# 32      대전광역시 서구 월평동 507번지  2~6층   2001-02-05   50   10   40
# 39          대전광역시 서구 탄방동 716번지     2001-12-15   50    2   48
# 62    대전광역시 서구 둔산동 1359번지  1~11층   2013-06-04   54    0   54
# 52      대전광역시 서구 월평동 511번지  3~8층   2003-03-19   54    3   51
# 72   대전광역시 서구 둔산동 1351번지  2층~12층   2014-05-14   55    0   55
# 43      대전광역시 서구 월평동 516번지  3~8층   2004-12-09   66    0   66
# 71    대전광역시 서구 둔산동 922번지  15~18층   2013-09-30   67    0   67
# 75         대전광역시 서구 둔산동 1351번지     2018-09-10   71    0   71
# 74     대전광역시 서구 탄방동 722번지  그랜드캐슬   2017-12-19  103    0  103
# 69    대전광역시 서구 둔산동 1356번지  2~10층   2012-12-17  106    3  103
# 73   대전광역시 서구 둔산동 1466번지  2층~12층   2014-12-03  128    0  128
# 67    대전광역시 서구 둔산동 1333번지  1~10층   2012-02-10  134    0  134
# 68    대전광역시 서구 둔산동 1314번지  1~11층   2012-02-28  134    0  134
# 70   대전광역시 서구 둔산동 1403번지  3층~15층   2013-09-11  211    7  204
# 63     대전광역시 서구 둔산동 922번지  3~14층   2013-09-30  300    0  300

# %%
accom_sorted.plot(kind='barh',x='업소명',y='객실수',figsize=(20,15))
plt.show()
